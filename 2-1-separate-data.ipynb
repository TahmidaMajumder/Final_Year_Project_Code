# %% [markdown]
# # **1. Separate Data:**
#
# - Separate Data based on the location

# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# remove warnings
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %% [markdown]
# # **2. Loading the Raw Data**

# %%
# Loading the data
new_data = pd.read_csv(r"/kaggle/input/for-separation/new_data_2015_2024.csv")

# print the shape
print(new_data.shape)

#runs the first 5 rows
new_data.head()
# Out:
# (1339286, 14)
#    Unnamed: 0        Date  Country       City   co   no2  o3  pm10  pm25  so2  \
# 0           0  2014-12-29  Austria       Graz  0.1   9.0 NaN  13.0   NaN  1.6
# 1           1  2014-12-29  Austria  Innsbruck  0.1  25.6 NaN  25.0   NaN  1.6
# 2           2  2014-12-29  Austria       Linz  0.1  14.2 NaN  25.0  74.0  2.1
# 3           3  2014-12-29  Austria   Salzburg  0.1  21.1 NaN  21.0   NaN  2.1
# 4           4  2014-12-29  Austria     Vienna  0.1   9.0 NaN  20.0  65.0  2.6
#
#    humidity  pressure  temperature  wind-speed
# 0       NaN       NaN          NaN         NaN
# 1       NaN       NaN          NaN         NaN
# 2       NaN       NaN          NaN         NaN
# 3       NaN       NaN          NaN         NaN
# 4       NaN       NaN          NaN         NaN

# %%
# Find the minimum and maximum dates
min_date = new_data['Date'].min()
max_date = new_data['Date'].max()

print('Minimum date:', min_date)
print('Maximum date:', max_date)
# Out:
# Minimum date: 2014-12-29
# Maximum date: 2025-01-09

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339286 entries, 0 to 1339285
# Data columns (total 14 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Unnamed: 0   1339286 non-null  int64
#  1   Date         1339286 non-null  object
#  2   Country      1339286 non-null  object
#  3   City         1339286 non-null  object
#  4   co           882878 non-null   float64
#  5   no2          1153213 non-null  float64
#  6   o3           1077987 non-null  float64
#  7   pm10         1150739 non-null  float64
#  8   pm25         1186937 non-null  float64
#  9   so2          958003 non-null   float64
#  10  humidity     1003804 non-null  float64
#  11  pressure     999758 non-null   float64
#  12  temperature  1004627 non-null  float64
#  13  wind-speed   946677 non-null   float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 143.1+ MB

# %%
new_data['Country_City'] = new_data['Country'] + '_' + new_data['City']

# %%
new_data.head()
# Out:
#    Unnamed: 0        Date  Country       City   co   no2  o3  pm10  pm25  so2  \
# 0           0  2014-12-29  Austria       Graz  0.1   9.0 NaN  13.0   NaN  1.6
# 1           1  2014-12-29  Austria  Innsbruck  0.1  25.6 NaN  25.0   NaN  1.6
# 2           2  2014-12-29  Austria       Linz  0.1  14.2 NaN  25.0  74.0  2.1
# 3           3  2014-12-29  Austria   Salzburg  0.1  21.1 NaN  21.0   NaN  2.1
# 4           4  2014-12-29  Austria     Vienna  0.1   9.0 NaN  20.0  65.0  2.6
#
#    humidity  pressure  temperature  wind-speed       Country_City
# 0       NaN       NaN          NaN         NaN       Austria_Graz
# 1       NaN       NaN          NaN         NaN  Austria_Innsbruck
# 2       NaN       NaN          NaN         NaN       Austria_Linz
# 3       NaN       NaN          NaN         NaN   Austria_Salzburg
# 4       NaN       NaN          NaN         NaN     Austria_Vienna

# %%
spain_data = new_data[new_data['Country_City'].str.contains('Spain')]
print(spain_data['Country_City'].unique())
# Out:
# ['Spain_Barcelona' 'Spain_Bilbao' 'Spain_Burgos'
#  'Spain_Castelló de la Plana' 'Spain_Donostia / San Sebastián'
#  'Spain_Gasteiz / Vitoria' 'Spain_Las Palmas de Gran Canaria'
#  'Spain_Madrid' 'Spain_Murcia' 'Spain_Oviedo' 'Spain_Pamplona'
#  'Spain_Salamanca' 'Spain_Santa Cruz de Tenerife' 'Spain_Santander'
#  'Spain_Valencia' 'Spain_Córdoba' 'Spain_Granada' 'Spain_Málaga'
#  'Spain_Sevilla' 'Spain_Huelva' 'Spain_Palma' 'Spain_Valladolid'
#  'Spain_Zaragoza']

# %%
# changing the name of two location
new_data['Country_City'] = new_data['Country_City'].replace('Spain_Donostia / San Sebastián', 'Spain_Donostia San Sebastián')
new_data['Country_City'] = new_data['Country_City'].replace('Spain_Gasteiz / Vitoria', 'Spain_Gasteiz Vitoria')

# %%
spain_data = new_data[new_data['Country_City'].str.contains('Spain')]
print(spain_data['Country_City'].unique())
# Out:
# ['Spain_Barcelona' 'Spain_Bilbao' 'Spain_Burgos'
#  'Spain_Castelló de la Plana' 'Spain_Donostia San Sebastián'
#  'Spain_Gasteiz Vitoria' 'Spain_Las Palmas de Gran Canaria' 'Spain_Madrid'
#  'Spain_Murcia' 'Spain_Oviedo' 'Spain_Pamplona' 'Spain_Salamanca'
#  'Spain_Santa Cruz de Tenerife' 'Spain_Santander' 'Spain_Valencia'
#  'Spain_Córdoba' 'Spain_Granada' 'Spain_Málaga' 'Spain_Sevilla'
#  'Spain_Huelva' 'Spain_Palma' 'Spain_Valladolid' 'Spain_Zaragoza']

# %%
# removing columns where missing values is more than 800,000
new_data = new_data.drop(['Unnamed: 0','Country', 'City'], axis=1)

# %%
new_data.columns
# Out:
# Index(['Date', 'co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'humidity',
#        'pressure', 'temperature', 'wind-speed', 'Country_City'],
#       dtype='object')

# %%
# Group by the 'Country_City' column
grouped = new_data.groupby('Country_City')

# Save each group as a separate CSV file
for location, group in grouped:
    # filename based on the location
    location = location.strip() + '.csv'
    group.to_csv(location, index=False)
    print(f"Saved dataset for {location} as {location}")
# Out:
# Saved dataset for Afghanistan_Kabul.csv as Afghanistan_Kabul.csv
# Saved dataset for Algeria_Algiers.csv as Algeria_Algiers.csv
# Saved dataset for Argentina_Buenos Aires.csv as Argentina_Buenos Aires.csv
# Saved dataset for Australia_Adelaide.csv as Australia_Adelaide.csv
# Saved dataset for Australia_Brisbane.csv as Australia_Brisbane.csv
# Saved dataset for Australia_Canberra.csv as Australia_Canberra.csv
# Saved dataset for Australia_Darwin.csv as Australia_Darwin.csv
# Saved dataset for Australia_Hobart.csv as Australia_Hobart.csv
# Saved dataset for Australia_Launceston.csv as Australia_Launceston.csv
# Saved dataset for Australia_Melbourne.csv as Australia_Melbourne.csv
# Saved dataset for Australia_Newcastle.csv as Australia_Newcastle.csv
# Saved dataset for Australia_Perth.csv as Australia_Perth.csv
# Saved dataset for Australia_Sydney.csv as Australia_Sydney.csv
# Saved dataset for Australia_Wollongong.csv as Australia_Wollongong.csv
# Saved dataset for Austria_Graz.csv as Austria_Graz.csv
# Saved dataset for Austria_Innsbruck.csv as Austria_Innsbruck.csv
# Saved dataset for Austria_Linz.csv as Austria_Linz.csv
# Saved dataset for Austria_Salzburg.csv as Austria_Salzburg.csv
# Saved dataset for Austria_Vienna.csv as Austria_Vienna.csv
# Saved dataset for Bahrain_Manama.csv as Bahrain_Manama.csv
# Saved dataset for Bangladesh_Dhaka.csv as Bangladesh_Dhaka.csv
# Saved dataset for Belgium_Antwerpen.csv as Belgium_Antwerpen.csv
# Saved dataset for Belgium_Brussels.csv as Belgium_Brussels.csv
# Saved dataset for Belgium_Charleroi.csv as Belgium_Charleroi.csv
# Saved dataset for Belgium_Gent.csv as Belgium_Gent.csv
# Saved dataset for Belgium_Liège.csv as Belgium_Liège.csv
# Saved dataset for Belgium_Namur.csv as Belgium_Namur.csv
# Saved dataset for Bolivia_Cochabamba.csv as Bolivia_Cochabamba.csv
# Saved dataset for Bosnia and Herzegovina_Sarajevo.csv as Bosnia and Herzegovina_Sarajevo.csv
# Saved dataset for Bosnia and Herzegovina_Tuzla.csv as Bosnia and Herzegovina_Tuzla.csv
# Saved dataset for Bosnia and Herzegovina_Zenica.csv as Bosnia and Herzegovina_Zenica.csv
# Saved dataset for Brazil_São José dos Campos.csv as Brazil_São José dos Campos.csv
# Saved dataset for Brazil_São Paulo.csv as Brazil_São Paulo.csv
# Saved dataset for Brazil_Vitória.csv as Brazil_Vitória.csv
# Saved dataset for Bulgaria_Burgas.csv as Bulgaria_Burgas.csv
# Saved dataset for Bulgaria_Plovdiv.csv as Bulgaria_Plovdiv.csv
# Saved dataset for Bulgaria_Sofia.csv as Bulgaria_Sofia.csv
# Saved dataset for Canada_Calgary.csv as Canada_Calgary.csv
# Saved dataset for Canada_Edmonton.csv as Canada_Edmonton.csv
# Saved dataset for Canada_Halifax.csv as Canada_Halifax.csv
# Saved dataset for Canada_Hamilton.csv as Canada_Hamilton.csv
# Saved dataset for Canada_Kitchener.csv as Canada_Kitchener.csv
# Saved dataset for Canada_London.csv as Canada_London.csv
# Saved dataset for Canada_Mississauga.csv as Canada_Mississauga.csv
# Saved dataset for Canada_Montréal.csv as Canada_Montréal.csv
# Saved dataset for Canada_Ottawa.csv as Canada_Ottawa.csv
# Saved dataset for Canada_Québec.csv as Canada_Québec.csv
# Saved dataset for Canada_Surrey.csv as Canada_Surrey.csv
# Saved dataset for Canada_Toronto.csv as Canada_Toronto.csv
# Saved dataset for Canada_Vancouver.csv as Canada_Vancouver.csv
# Saved dataset for Canada_Victoria.csv as Canada_Victoria.csv
# Saved dataset for Canada_Winnipeg.csv as Canada_Winnipeg.csv
# Saved dataset for Chile_Calama.csv as Chile_Calama.csv
# Saved dataset for Chile_Chillán.csv as Chile_Chillán.csv
# Saved dataset for Chile_Concepción.csv as Chile_Concepción.csv
# Saved dataset for Chile_Los Ángeles.csv as Chile_Los Ángeles.csv
# Saved dataset for Chile_Osorno.csv as Chile_Osorno.csv
# Saved dataset for Chile_Puerto Montt.csv as Chile_Puerto Montt.csv
# Saved dataset for Chile_Quilpué.csv as Chile_Quilpué.csv
# Saved dataset for Chile_Rancagua.csv as Chile_Rancagua.csv
# Saved dataset for Chile_Santiago.csv as Chile_Santiago.csv
# Saved dataset for Chile_Talca.csv as Chile_Talca.csv
# Saved dataset for Chile_Temuco.csv as Chile_Temuco.csv
# Saved dataset for Chile_Valparaíso.csv as Chile_Valparaíso.csv
# Saved dataset for China_Anyang.csv as China_Anyang.csv
# Saved dataset for China_Beijing.csv as China_Beijing.csv
# Saved dataset for China_Changchun.csv as China_Changchun.csv
# Saved dataset for China_Changsha.csv as China_Changsha.csv
# Saved dataset for China_Changzhou.csv as China_Changzhou.csv
# Saved dataset for China_Chengdu.csv as China_Chengdu.csv
# Saved dataset for China_Chongqing.csv as China_Chongqing.csv
# Saved dataset for China_Dongguan.csv as China_Dongguan.csv
# Saved dataset for China_Foshan.csv as China_Foshan.csv
# Saved dataset for China_Fushun.csv as China_Fushun.csv
# Saved dataset for China_Fuzhou.csv as China_Fuzhou.csv
# Saved dataset for China_Guangzhou.csv as China_Guangzhou.csv
# Saved dataset for China_Guiyang.csv as China_Guiyang.csv
# Saved dataset for China_Haikou.csv as China_Haikou.csv
# Saved dataset for China_Hangzhou.csv as China_Hangzhou.csv
# Saved dataset for China_Harbin.csv as China_Harbin.csv
# Saved dataset for China_Hefei.csv as China_Hefei.csv
# Saved dataset for China_Hegang.csv as China_Hegang.csv
# Saved dataset for China_Hohhot.csv as China_Hohhot.csv
# Saved dataset for China_Jieyang.csv as China_Jieyang.csv
# Saved dataset for China_Jinan.csv as China_Jinan.csv
# Saved dataset for China_Kunming.csv as China_Kunming.csv
# Saved dataset for China_Lanzhou.csv as China_Lanzhou.csv
# Saved dataset for China_Lhasa.csv as China_Lhasa.csv
# Saved dataset for China_Nanchang.csv as China_Nanchang.csv
# Saved dataset for China_Nanjing.csv as China_Nanjing.csv
# Saved dataset for China_Nanning.csv as China_Nanning.csv
# Saved dataset for China_Ningbo.csv as China_Ningbo.csv
# Saved dataset for China_Qingdao.csv as China_Qingdao.csv
# Saved dataset for China_Qinhuangdao.csv as China_Qinhuangdao.csv
# Saved dataset for China_Qiqihar.csv as China_Qiqihar.csv
# Saved dataset for China_Shanghai.csv as China_Shanghai.csv
# Saved dataset for China_Shantou.csv as China_Shantou.csv
# Saved dataset for China_Shenyang.csv as China_Shenyang.csv
# Saved dataset for China_Shenzhen.csv as China_Shenzhen.csv
# Saved dataset for China_Shijiazhuang.csv as China_Shijiazhuang.csv
# Saved dataset for China_Shiyan.csv as China_Shiyan.csv
# Saved dataset for China_Suzhou.csv as China_Suzhou.csv
# Saved dataset for China_Taiyuan.csv as China_Taiyuan.csv
# Saved dataset for China_Tianjin.csv as China_Tianjin.csv
# Saved dataset for China_Wuhan.csv as China_Wuhan.csv
# Saved dataset for China_Wuxi.csv as China_Wuxi.csv
# Saved dataset for China_Xiamen.csv as China_Xiamen.csv
# Saved dataset for China_Xining.csv as China_Xining.csv
# Saved dataset for China_Xinxiang.csv as China_Xinxiang.csv
# Saved dataset for China_Xi’an.csv as China_Xi’an.csv
# Saved dataset for China_Xuchang.csv as China_Xuchang.csv
# Saved dataset for China_Yinchuan.csv as China_Yinchuan.csv
# Saved dataset for China_Yunfu.csv as China_Yunfu.csv
# Saved dataset for China_Zhengzhou.csv as China_Zhengzhou.csv
# Saved dataset for China_Zhuzhou.csv as China_Zhuzhou.csv
# Saved dataset for China_Ürümqi.csv as China_Ürümqi.csv
# Saved dataset for Colombia_Bogotá.csv as Colombia_Bogotá.csv
# Saved dataset for Colombia_Medellín.csv as Colombia_Medellín.csv
# Saved dataset for Costa Rica_San José.csv as Costa Rica_San José.csv
# Saved dataset for Croatia_Rijeka.csv as Croatia_Rijeka.csv
# Saved dataset for Croatia_Split.csv as Croatia_Split.csv
# Saved dataset for Croatia_Zagreb.csv as Croatia_Zagreb.csv
# Saved dataset for Curaçao_Willemstad.csv as Curaçao_Willemstad.csv
# Saved dataset for Cyprus_Limassol.csv as Cyprus_Limassol.csv
# Saved dataset for Cyprus_Nicosia.csv as Cyprus_Nicosia.csv
# Saved dataset for Czechia_Brno.csv as Czechia_Brno.csv
# Saved dataset for Czechia_Olomouc.csv as Czechia_Olomouc.csv
# Saved dataset for Czechia_Ostrava.csv as Czechia_Ostrava.csv
# Saved dataset for Czechia_Pilsen.csv as Czechia_Pilsen.csv
# Saved dataset for Czechia_Prague.csv as Czechia_Prague.csv
# Saved dataset for Denmark_Copenhagen.csv as Denmark_Copenhagen.csv
# Saved dataset for Ecuador_Quito.csv as Ecuador_Quito.csv
# Saved dataset for El Salvador_San Salvador.csv as El Salvador_San Salvador.csv
# Saved dataset for Estonia_Tallinn.csv as Estonia_Tallinn.csv
# Saved dataset for Ethiopia_Addis Ababa.csv as Ethiopia_Addis Ababa.csv
# Saved dataset for Finland_Helsinki.csv as Finland_Helsinki.csv
# Saved dataset for Finland_Oulu.csv as Finland_Oulu.csv
# Saved dataset for Finland_Tampere.csv as Finland_Tampere.csv
# Saved dataset for Finland_Turku.csv as Finland_Turku.csv
# Saved dataset for Finland_Vantaa.csv as Finland_Vantaa.csv
# Saved dataset for France_Amiens.csv as France_Amiens.csv
# Saved dataset for France_Besançon.csv as France_Besançon.csv
# Saved dataset for France_Bordeaux.csv as France_Bordeaux.csv
# Saved dataset for France_Caen.csv as France_Caen.csv
# Saved dataset for France_Clermont-Ferrand.csv as France_Clermont-Ferrand.csv
# Saved dataset for France_Dijon.csv as France_Dijon.csv
# Saved dataset for France_Grenoble.csv as France_Grenoble.csv
# Saved dataset for France_Lille.csv as France_Lille.csv
# Saved dataset for France_Limoges.csv as France_Limoges.csv
# Saved dataset for France_Lyon.csv as France_Lyon.csv
# Saved dataset for France_Marseille.csv as France_Marseille.csv
# Saved dataset for France_Metz.csv as France_Metz.csv
# Saved dataset for France_Montpellier.csv as France_Montpellier.csv
# Saved dataset for France_Nancy.csv as France_Nancy.csv
# Saved dataset for France_Nantes.csv as France_Nantes.csv
# Saved dataset for France_Nice.csv as France_Nice.csv
# Saved dataset for France_Nîmes.csv as France_Nîmes.csv
# Saved dataset for France_Orléans.csv as France_Orléans.csv
# Saved dataset for France_Paris.csv as France_Paris.csv
# Saved dataset for France_Perpignan.csv as France_Perpignan.csv
# Saved dataset for France_Rennes.csv as France_Rennes.csv
# Saved dataset for France_Rouen.csv as France_Rouen.csv
# Saved dataset for France_Saint-Étienne.csv as France_Saint-Étienne.csv
# Saved dataset for France_Strasbourg.csv as France_Strasbourg.csv
# Saved dataset for France_Toulon.csv as France_Toulon.csv
# Saved dataset for France_Toulouse.csv as France_Toulouse.csv
# Saved dataset for France_Tours.csv as France_Tours.csv
# Saved dataset for Georgia_Tbilisi.csv as Georgia_Tbilisi.csv
# Saved dataset for Germany_Augsburg.csv as Germany_Augsburg.csv
# Saved dataset for Germany_Berlin.csv as Germany_Berlin.csv
# Saved dataset for Germany_Darmstadt.csv as Germany_Darmstadt.csv
# Saved dataset for Germany_Dresden.csv as Germany_Dresden.csv
# Saved dataset for Germany_Düsseldorf.csv as Germany_Düsseldorf.csv
# Saved dataset for Germany_Freiburg.csv as Germany_Freiburg.csv
# Saved dataset for Germany_Hamburg.csv as Germany_Hamburg.csv
# Saved dataset for Germany_Hannover.csv as Germany_Hannover.csv
# Saved dataset for Germany_Karlsruhe.csv as Germany_Karlsruhe.csv
# Saved dataset for Germany_Kassel.csv as Germany_Kassel.csv
# Saved dataset for Germany_Köln.csv as Germany_Köln.csv
# Saved dataset for Germany_Mainz.csv as Germany_Mainz.csv
# Saved dataset for Germany_Munich.csv as Germany_Munich.csv
# Saved dataset for Germany_Münster.csv as Germany_Münster.csv
# Saved dataset for Germany_Potsdam.csv as Germany_Potsdam.csv
# Saved dataset for Germany_Stuttgart.csv as Germany_Stuttgart.csv
# Saved dataset for Germany_Wiesbaden.csv as Germany_Wiesbaden.csv
# Saved dataset for Ghana_Accra.csv as Ghana_Accra.csv
# Saved dataset for Greece_Athens.csv as Greece_Athens.csv
# Saved dataset for Greece_Thessaloníki.csv as Greece_Thessaloníki.csv
# Saved dataset for Guatemala_Guatemala City.csv as Guatemala_Guatemala City.csv
# Saved dataset for Guinea_Conakry.csv as Guinea_Conakry.csv
# Saved dataset for Hong Kong_Hong Kong.csv as Hong Kong_Hong Kong.csv
# Saved dataset for Hungary_Budapest.csv as Hungary_Budapest.csv
# Saved dataset for Hungary_Debrecen.csv as Hungary_Debrecen.csv
# Saved dataset for Hungary_Győr.csv as Hungary_Győr.csv
# Saved dataset for Hungary_Kecskemét.csv as Hungary_Kecskemét.csv
# Saved dataset for Hungary_Miskolc.csv as Hungary_Miskolc.csv
# Saved dataset for Hungary_Pécs.csv as Hungary_Pécs.csv
# Saved dataset for Hungary_Szeged.csv as Hungary_Szeged.csv
# Saved dataset for Iceland_Reykjavík.csv as Iceland_Reykjavík.csv
# Saved dataset for India_Bengaluru.csv as India_Bengaluru.csv
# Saved dataset for India_Bhopal.csv as India_Bhopal.csv
# Saved dataset for India_Chandigarh.csv as India_Chandigarh.csv
# Saved dataset for India_Chennai.csv as India_Chennai.csv
# Saved dataset for India_Delhi.csv as India_Delhi.csv
# Saved dataset for India_Gandhinagar.csv as India_Gandhinagar.csv
# Saved dataset for India_Ghāziābād.csv as India_Ghāziābād.csv
# Saved dataset for India_Hyderabad.csv as India_Hyderabad.csv
# Saved dataset for India_Hāpur.csv as India_Hāpur.csv
# Saved dataset for India_Jaipur.csv as India_Jaipur.csv
# Saved dataset for India_Kolkata.csv as India_Kolkata.csv
# Saved dataset for India_Lucknow.csv as India_Lucknow.csv
# Saved dataset for India_Mumbai.csv as India_Mumbai.csv
# Saved dataset for India_Muzaffarnagar.csv as India_Muzaffarnagar.csv
# Saved dataset for India_Mysore.csv as India_Mysore.csv
# Saved dataset for India_Nagpur.csv as India_Nagpur.csv
# Saved dataset for India_Nashik.csv as India_Nashik.csv
# Saved dataset for India_New Delhi.csv as India_New Delhi.csv
# Saved dataset for India_Patna.csv as India_Patna.csv
# Saved dataset for India_Shillong.csv as India_Shillong.csv
# Saved dataset for India_Thiruvananthapuram.csv as India_Thiruvananthapuram.csv
# Saved dataset for India_Thrissur.csv as India_Thrissur.csv
# Saved dataset for India_Visakhapatnam.csv as India_Visakhapatnam.csv
# Saved dataset for Indonesia_Jakarta.csv as Indonesia_Jakarta.csv
# Saved dataset for Iran_Arāk.csv as Iran_Arāk.csv
# Saved dataset for Iran_Bandar Abbas.csv as Iran_Bandar Abbas.csv
# Saved dataset for Iran_Isfahan.csv as Iran_Isfahan.csv
# Saved dataset for Iran_Karaj.csv as Iran_Karaj.csv
# Saved dataset for Iran_Kerman.csv as Iran_Kerman.csv
# Saved dataset for Iran_Kermanshah.csv as Iran_Kermanshah.csv
# Saved dataset for Iran_Khorramabad.csv as Iran_Khorramabad.csv
# Saved dataset for Iran_Khorramshahr.csv as Iran_Khorramshahr.csv
# Saved dataset for Iran_Mashhad.csv as Iran_Mashhad.csv
# Saved dataset for Iran_Orūmīyeh.csv as Iran_Orūmīyeh.csv
# Saved dataset for Iran_Qom.csv as Iran_Qom.csv
# Saved dataset for Iran_Sanandaj.csv as Iran_Sanandaj.csv
# Saved dataset for Iran_Shiraz.csv as Iran_Shiraz.csv
# Saved dataset for Iran_Tabriz.csv as Iran_Tabriz.csv
# Saved dataset for Iran_Tehran.csv as Iran_Tehran.csv
# Saved dataset for Iran_Yazd.csv as Iran_Yazd.csv
# Saved dataset for Iran_Zanjān.csv as Iran_Zanjān.csv
# Saved dataset for Iran_Īlām.csv as Iran_Īlām.csv
# Saved dataset for Iraq_Baghdad.csv as Iraq_Baghdad.csv
# Saved dataset for Ireland_Dublin.csv as Ireland_Dublin.csv
# Saved dataset for Israel_Ashdod.csv as Israel_Ashdod.csv
# Saved dataset for Israel_Ashkelon.csv as Israel_Ashkelon.csv
# Saved dataset for Israel_Haifa.csv as Israel_Haifa.csv
# Saved dataset for Israel_Jerusalem.csv as Israel_Jerusalem.csv
# Saved dataset for Israel_Netanya.csv as Israel_Netanya.csv
# Saved dataset for Israel_Petaẖ Tiqwa.csv as Israel_Petaẖ Tiqwa.csv
# Saved dataset for Israel_Tel Aviv.csv as Israel_Tel Aviv.csv
# Saved dataset for Italy_Bologna.csv as Italy_Bologna.csv
# Saved dataset for Italy_Brescia.csv as Italy_Brescia.csv
# Saved dataset for Italy_Florence.csv as Italy_Florence.csv
# Saved dataset for Italy_Livorno.csv as Italy_Livorno.csv
# Saved dataset for Italy_Milan.csv as Italy_Milan.csv
# Saved dataset for Italy_Modena.csv as Italy_Modena.csv
# Saved dataset for Italy_Naples.csv as Italy_Naples.csv
# Saved dataset for Italy_Parma.csv as Italy_Parma.csv
# Saved dataset for Italy_Prato.csv as Italy_Prato.csv
# Saved dataset for Italy_Rome.csv as Italy_Rome.csv
# Saved dataset for Italy_Trieste.csv as Italy_Trieste.csv
# Saved dataset for Italy_Turin.csv as Italy_Turin.csv
# Saved dataset for Ivory Coast_Abidjan.csv as Ivory Coast_Abidjan.csv
# Saved dataset for Japan_Akita.csv as Japan_Akita.csv
# Saved dataset for Japan_Chiba.csv as Japan_Chiba.csv
# Saved dataset for Japan_Fukuoka.csv as Japan_Fukuoka.csv
# Saved dataset for Japan_Gifu-shi.csv as Japan_Gifu-shi.csv
# Saved dataset for Japan_Hiroshima.csv as Japan_Hiroshima.csv
# Saved dataset for Japan_Kagoshima.csv as Japan_Kagoshima.csv
# Saved dataset for Japan_Kanazawa.csv as Japan_Kanazawa.csv
# Saved dataset for Japan_Kobe.csv as Japan_Kobe.csv
# Saved dataset for Japan_Kochi.csv as Japan_Kochi.csv
# Saved dataset for Japan_Kumamoto.csv as Japan_Kumamoto.csv
# Saved dataset for Japan_Kyoto.csv as Japan_Kyoto.csv
# Saved dataset for Japan_Matsuyama.csv as Japan_Matsuyama.csv
# Saved dataset for Japan_Miyazaki.csv as Japan_Miyazaki.csv
# Saved dataset for Japan_Nagano.csv as Japan_Nagano.csv
# Saved dataset for Japan_Nagasaki.csv as Japan_Nagasaki.csv
# Saved dataset for Japan_Nagoya.csv as Japan_Nagoya.csv
# Saved dataset for Japan_Naha.csv as Japan_Naha.csv
# Saved dataset for Japan_Nara-shi.csv as Japan_Nara-shi.csv
# Saved dataset for Japan_Niigata.csv as Japan_Niigata.csv
# Saved dataset for Japan_Okayama.csv as Japan_Okayama.csv
# Saved dataset for Japan_Osaka.csv as Japan_Osaka.csv
# Saved dataset for Japan_Saitama.csv as Japan_Saitama.csv
# Saved dataset for Japan_Sapporo.csv as Japan_Sapporo.csv
# Saved dataset for Japan_Sendai.csv as Japan_Sendai.csv
# Saved dataset for Japan_Shizuoka.csv as Japan_Shizuoka.csv
# Saved dataset for Japan_Takamatsu.csv as Japan_Takamatsu.csv
# Saved dataset for Japan_Tokyo.csv as Japan_Tokyo.csv
# Saved dataset for Japan_Toyama.csv as Japan_Toyama.csv
# Saved dataset for Japan_Utsunomiya.csv as Japan_Utsunomiya.csv
# Saved dataset for Japan_Wakayama.csv as Japan_Wakayama.csv
# Saved dataset for Japan_Yokohama.csv as Japan_Yokohama.csv
# Saved dataset for Japan_Ōita.csv as Japan_Ōita.csv
# Saved dataset for Jordan_Amman.csv as Jordan_Amman.csv
# Saved dataset for Jordan_Irbid.csv as Jordan_Irbid.csv
# Saved dataset for Jordan_Zarqa.csv as Jordan_Zarqa.csv
# Saved dataset for Kazakhstan_Almaty.csv as Kazakhstan_Almaty.csv
# Saved dataset for Kazakhstan_Nur-Sultan.csv as Kazakhstan_Nur-Sultan.csv
# Saved dataset for Kosovo_Pristina.csv as Kosovo_Pristina.csv
# Saved dataset for Kuwait_Ḩawallī.csv as Kuwait_Ḩawallī.csv
# Saved dataset for Kyrgyzstan_Bishkek.csv as Kyrgyzstan_Bishkek.csv
# Saved dataset for Laos_Vientiane.csv as Laos_Vientiane.csv
# Saved dataset for Lithuania_Kaunas.csv as Lithuania_Kaunas.csv
# Saved dataset for Macao_Macau.csv as Macao_Macau.csv
# Saved dataset for Mali_Bamako.csv as Mali_Bamako.csv
# Saved dataset for Mexico_Aguascalientes.csv as Mexico_Aguascalientes.csv
# Saved dataset for Mexico_Chihuahua.csv as Mexico_Chihuahua.csv
# Saved dataset for Mexico_Cuernavaca.csv as Mexico_Cuernavaca.csv
# Saved dataset for Mexico_Ecatepec de Morelos.csv as Mexico_Ecatepec de Morelos.csv
# Saved dataset for Mexico_Guadalajara.csv as Mexico_Guadalajara.csv
# Saved dataset for Mexico_Mexico City.csv as Mexico_Mexico City.csv
# Saved dataset for Mexico_Monterrey.csv as Mexico_Monterrey.csv
# Saved dataset for Mexico_Morelia.csv as Mexico_Morelia.csv
# Saved dataset for Mexico_Mérida.csv as Mexico_Mérida.csv
# Saved dataset for Mexico_Oaxaca.csv as Mexico_Oaxaca.csv
# Saved dataset for Mexico_Pachuca de Soto.csv as Mexico_Pachuca de Soto.csv
# Saved dataset for Mexico_Puebla.csv as Mexico_Puebla.csv
# Saved dataset for Mexico_San Luis Potosí.csv as Mexico_San Luis Potosí.csv
# Saved dataset for Mexico_Tepic.csv as Mexico_Tepic.csv
# Saved dataset for Mexico_Toluca.csv as Mexico_Toluca.csv
# Saved dataset for Mongolia_Ulan Bator.csv as Mongolia_Ulan Bator.csv
# Saved dataset for Myanmar_Yangon.csv as Myanmar_Yangon.csv
# Saved dataset for Nepal_Biratnagar.csv as Nepal_Biratnagar.csv
# Saved dataset for Nepal_Kathmandu.csv as Nepal_Kathmandu.csv
# Saved dataset for Nepal_Pokhara.csv as Nepal_Pokhara.csv
# Saved dataset for New Zealand_Auckland.csv as New Zealand_Auckland.csv
# Saved dataset for New Zealand_Christchurch.csv as New Zealand_Christchurch.csv
# Saved dataset for New Zealand_Dunedin.csv as New Zealand_Dunedin.csv
# Saved dataset for New Zealand_Hamilton.csv as New Zealand_Hamilton.csv
# Saved dataset for New Zealand_Wellington.csv as New Zealand_Wellington.csv
# Saved dataset for North Macedonia_Skopje.csv as North Macedonia_Skopje.csv
# Saved dataset for Norway_Bergen.csv as Norway_Bergen.csv
# Saved dataset for Norway_Oslo.csv as Norway_Oslo.csv
# Saved dataset for Norway_Stavanger.csv as Norway_Stavanger.csv
# Saved dataset for Norway_Trondheim.csv as Norway_Trondheim.csv
# Saved dataset for Pakistan_Islamabad.csv as Pakistan_Islamabad.csv
# Saved dataset for Pakistan_Karachi.csv as Pakistan_Karachi.csv
# Saved dataset for Pakistan_Lahore.csv as Pakistan_Lahore.csv
# Saved dataset for Pakistan_Peshawar.csv as Pakistan_Peshawar.csv
# Saved dataset for Peru_Lima.csv as Peru_Lima.csv
# Saved dataset for Philippines_Baguio.csv as Philippines_Baguio.csv
# Saved dataset for Philippines_Butuan.csv as Philippines_Butuan.csv
# Saved dataset for Philippines_Manila.csv as Philippines_Manila.csv
# Saved dataset for Philippines_Zamboanga.csv as Philippines_Zamboanga.csv
# Saved dataset for Poland_Bydgoszcz.csv as Poland_Bydgoszcz.csv
# Saved dataset for Poland_Gdańsk.csv as Poland_Gdańsk.csv
# Saved dataset for Poland_Katowice.csv as Poland_Katowice.csv
# Saved dataset for Poland_Kielce.csv as Poland_Kielce.csv
# Saved dataset for Poland_Kraków.csv as Poland_Kraków.csv
# Saved dataset for Poland_Poznań.csv as Poland_Poznań.csv
# Saved dataset for Poland_Płock.csv as Poland_Płock.csv
# Saved dataset for Poland_Rybnik.csv as Poland_Rybnik.csv
# Saved dataset for Poland_Szczecin.csv as Poland_Szczecin.csv
# Saved dataset for Poland_Tarnów.csv as Poland_Tarnów.csv
# Saved dataset for Poland_Warsaw.csv as Poland_Warsaw.csv
# Saved dataset for Poland_Wrocław.csv as Poland_Wrocław.csv
# Saved dataset for Poland_Zabrze.csv as Poland_Zabrze.csv
# Saved dataset for Poland_Łódź.csv as Poland_Łódź.csv
# Saved dataset for Portugal_Funchal.csv as Portugal_Funchal.csv
# Saved dataset for Portugal_Lisbon.csv as Portugal_Lisbon.csv
# Saved dataset for Puerto Rico_San Juan.csv as Puerto Rico_San Juan.csv
# Saved dataset for Romania_Arad.csv as Romania_Arad.csv
# Saved dataset for Romania_Bacău.csv as Romania_Bacău.csv
# Saved dataset for Romania_Baia Mare.csv as Romania_Baia Mare.csv
# Saved dataset for Romania_Braşov.csv as Romania_Braşov.csv
# Saved dataset for Romania_Brăila.csv as Romania_Brăila.csv
# Saved dataset for Romania_Bucharest.csv as Romania_Bucharest.csv
# Saved dataset for Romania_Cluj-Napoca.csv as Romania_Cluj-Napoca.csv
# Saved dataset for Romania_Constanţa.csv as Romania_Constanţa.csv
# Saved dataset for Romania_Craiova.csv as Romania_Craiova.csv
# Saved dataset for Romania_Galaţi.csv as Romania_Galaţi.csv
# Saved dataset for Romania_Iaşi.csv as Romania_Iaşi.csv
# Saved dataset for Romania_Oradea.csv as Romania_Oradea.csv
# Saved dataset for Romania_Piteşti.csv as Romania_Piteşti.csv
# Saved dataset for Romania_Ploieşti.csv as Romania_Ploieşti.csv
# Saved dataset for Romania_Râmnicu Vâlcea.csv as Romania_Râmnicu Vâlcea.csv
# Saved dataset for Romania_Sibiu.csv as Romania_Sibiu.csv
# Saved dataset for Romania_Timişoara.csv as Romania_Timişoara.csv
# Saved dataset for Russia_Chelyabinsk.csv as Russia_Chelyabinsk.csv
# Saved dataset for Russia_Krasnoyarsk.csv as Russia_Krasnoyarsk.csv
# Saved dataset for Russia_Moscow.csv as Russia_Moscow.csv
# Saved dataset for Russia_Nizhniy Novgorod.csv as Russia_Nizhniy Novgorod.csv
# Saved dataset for Russia_Novosibirsk.csv as Russia_Novosibirsk.csv
# Saved dataset for Russia_Saint Petersburg.csv as Russia_Saint Petersburg.csv
# Saved dataset for Russia_Tomsk.csv as Russia_Tomsk.csv
# Saved dataset for Réunion_Saint-Denis.csv as Réunion_Saint-Denis.csv
# Saved dataset for Saudi Arabia_Abha.csv as Saudi Arabia_Abha.csv
# Saved dataset for Saudi Arabia_Buraydah.csv as Saudi Arabia_Buraydah.csv
# Saved dataset for Saudi Arabia_Dammam.csv as Saudi Arabia_Dammam.csv
# Saved dataset for Saudi Arabia_Ha'il.csv as Saudi Arabia_Ha'il.csv
# Saved dataset for Saudi Arabia_Jeddah.csv as Saudi Arabia_Jeddah.csv
# Saved dataset for Saudi Arabia_Mecca.csv as Saudi Arabia_Mecca.csv
# Saved dataset for Saudi Arabia_Riyadh.csv as Saudi Arabia_Riyadh.csv
# Saved dataset for Serbia_Belgrade.csv as Serbia_Belgrade.csv
# Saved dataset for Serbia_Niš.csv as Serbia_Niš.csv
# Saved dataset for Serbia_Novi Sad.csv as Serbia_Novi Sad.csv
# Saved dataset for Singapore_Singapore.csv as Singapore_Singapore.csv
# Saved dataset for Slovakia_Bratislava.csv as Slovakia_Bratislava.csv
# Saved dataset for Slovakia_Košice.csv as Slovakia_Košice.csv
# Saved dataset for South Africa_Bloemfontein.csv as South Africa_Bloemfontein.csv
# Saved dataset for South Africa_Cape Town.csv as South Africa_Cape Town.csv
# Saved dataset for South Africa_Durban.csv as South Africa_Durban.csv
# Saved dataset for South Africa_East London.csv as South Africa_East London.csv
# Saved dataset for South Africa_Johannesburg.csv as South Africa_Johannesburg.csv
# Saved dataset for South Africa_Klerksdorp.csv as South Africa_Klerksdorp.csv
# Saved dataset for South Africa_Middelburg.csv as South Africa_Middelburg.csv
# Saved dataset for South Africa_Port Elizabeth.csv as South Africa_Port Elizabeth.csv
# Saved dataset for South Africa_Pretoria.csv as South Africa_Pretoria.csv
# Saved dataset for South Africa_Richards Bay.csv as South Africa_Richards Bay.csv
# Saved dataset for South Africa_Vereeniging.csv as South Africa_Vereeniging.csv
# Saved dataset for South Africa_Worcester.csv as South Africa_Worcester.csv
# Saved dataset for South Korea_Andong.csv as South Korea_Andong.csv
# Saved dataset for South Korea_Busan.csv as South Korea_Busan.csv
# Saved dataset for South Korea_Changwon.csv as South Korea_Changwon.csv
# Saved dataset for South Korea_Cheongju-si.csv as South Korea_Cheongju-si.csv
# Saved dataset for South Korea_Chuncheon.csv as South Korea_Chuncheon.csv
# Saved dataset for South Korea_Daegu.csv as South Korea_Daegu.csv
# Saved dataset for South Korea_Daejeon.csv as South Korea_Daejeon.csv
# Saved dataset for South Korea_Gwangju.csv as South Korea_Gwangju.csv
# Saved dataset for South Korea_Incheon.csv as South Korea_Incheon.csv
# Saved dataset for South Korea_Jeju City.csv as South Korea_Jeju City.csv
# Saved dataset for South Korea_Jeonju.csv as South Korea_Jeonju.csv
# Saved dataset for South Korea_Mokpo.csv as South Korea_Mokpo.csv
# Saved dataset for South Korea_Pohang.csv as South Korea_Pohang.csv
# Saved dataset for South Korea_Sejong.csv as South Korea_Sejong.csv
# Saved dataset for South Korea_Seongnam-si.csv as South Korea_Seongnam-si.csv
# Saved dataset for South Korea_Seoul.csv as South Korea_Seoul.csv
# Saved dataset for South Korea_Suncheon.csv as South Korea_Suncheon.csv
# Saved dataset for South Korea_Suwon.csv as South Korea_Suwon.csv
# Saved dataset for South Korea_Ulsan.csv as South Korea_Ulsan.csv
# Saved dataset for South Korea_Yeosu.csv as South Korea_Yeosu.csv
# Saved dataset for Spain_Barcelona.csv as Spain_Barcelona.csv
# Saved dataset for Spain_Bilbao.csv as Spain_Bilbao.csv
# Saved dataset for Spain_Burgos.csv as Spain_Burgos.csv
# Saved dataset for Spain_Castelló de la Plana.csv as Spain_Castelló de la Plana.csv
# Saved dataset for Spain_Córdoba.csv as Spain_Córdoba.csv
# Saved dataset for Spain_Donostia San Sebastián.csv as Spain_Donostia San Sebastián.csv
# Saved dataset for Spain_Gasteiz Vitoria.csv as Spain_Gasteiz Vitoria.csv
# Saved dataset for Spain_Granada.csv as Spain_Granada.csv
# Saved dataset for Spain_Huelva.csv as Spain_Huelva.csv
# Saved dataset for Spain_Las Palmas de Gran Canaria.csv as Spain_Las Palmas de Gran Canaria.csv
# Saved dataset for Spain_Madrid.csv as Spain_Madrid.csv
# Saved dataset for Spain_Murcia.csv as Spain_Murcia.csv
# Saved dataset for Spain_Málaga.csv as Spain_Málaga.csv
# Saved dataset for Spain_Oviedo.csv as Spain_Oviedo.csv
# Saved dataset for Spain_Palma.csv as Spain_Palma.csv
# Saved dataset for Spain_Pamplona.csv as Spain_Pamplona.csv
# Saved dataset for Spain_Salamanca.csv as Spain_Salamanca.csv
# Saved dataset for Spain_Santa Cruz de Tenerife.csv as Spain_Santa Cruz de Tenerife.csv
# Saved dataset for Spain_Santander.csv as Spain_Santander.csv
# Saved dataset for Spain_Sevilla.csv as Spain_Sevilla.csv
# Saved dataset for Spain_Valencia.csv as Spain_Valencia.csv
# Saved dataset for Spain_Valladolid.csv as Spain_Valladolid.csv
# Saved dataset for Spain_Zaragoza.csv as Spain_Zaragoza.csv
# Saved dataset for Sri Lanka_Colombo.csv as Sri Lanka_Colombo.csv
# Saved dataset for Sweden_Göteborg.csv as Sweden_Göteborg.csv
# Saved dataset for Sweden_Malmö.csv as Sweden_Malmö.csv
# Saved dataset for Sweden_Stockholm.csv as Sweden_Stockholm.csv
# Saved dataset for Sweden_Uppsala.csv as Sweden_Uppsala.csv
# Saved dataset for Switzerland_Zürich.csv as Switzerland_Zürich.csv
# Saved dataset for Taiwan_Douliu.csv as Taiwan_Douliu.csv
# Saved dataset for Taiwan_Hsinchu.csv as Taiwan_Hsinchu.csv
# Saved dataset for Taiwan_Kaohsiung.csv as Taiwan_Kaohsiung.csv
# Saved dataset for Taiwan_Keelung.csv as Taiwan_Keelung.csv
# Saved dataset for Taiwan_Taichung.csv as Taiwan_Taichung.csv
# Saved dataset for Taiwan_Tainan.csv as Taiwan_Tainan.csv
# Saved dataset for Taiwan_Taipei.csv as Taiwan_Taipei.csv
# Saved dataset for Taiwan_Taitung City.csv as Taiwan_Taitung City.csv
# Saved dataset for Taiwan_Taoyuan City.csv as Taiwan_Taoyuan City.csv
# Saved dataset for Tajikistan_Dushanbe.csv as Tajikistan_Dushanbe.csv
# Saved dataset for Thailand_Bangkok.csv as Thailand_Bangkok.csv
# Saved dataset for Thailand_Chiang Mai.csv as Thailand_Chiang Mai.csv
# Saved dataset for Thailand_Chon Buri.csv as Thailand_Chon Buri.csv
# Saved dataset for Thailand_Lampang.csv as Thailand_Lampang.csv
# Saved dataset for Thailand_Nakhon Pathom.csv as Thailand_Nakhon Pathom.csv
# Saved dataset for Thailand_Rayong.csv as Thailand_Rayong.csv
# Saved dataset for Thailand_Samut Prakan.csv as Thailand_Samut Prakan.csv
# Saved dataset for The Netherlands_Amsterdam.csv as The Netherlands_Amsterdam.csv
# Saved dataset for The Netherlands_Breda.csv as The Netherlands_Breda.csv
# Saved dataset for The Netherlands_Dordrecht.csv as The Netherlands_Dordrecht.csv
# Saved dataset for The Netherlands_Eindhoven.csv as The Netherlands_Eindhoven.csv
# Saved dataset for The Netherlands_Groningen.csv as The Netherlands_Groningen.csv
# Saved dataset for The Netherlands_Haarlem.csv as The Netherlands_Haarlem.csv
# Saved dataset for The Netherlands_Maastricht.csv as The Netherlands_Maastricht.csv
# Saved dataset for The Netherlands_Nijmegen.csv as The Netherlands_Nijmegen.csv
# Saved dataset for The Netherlands_Rotterdam.csv as The Netherlands_Rotterdam.csv
# Saved dataset for The Netherlands_The Hague.csv as The Netherlands_The Hague.csv
# Saved dataset for The Netherlands_Utrecht.csv as The Netherlands_Utrecht.csv
# Saved dataset for Turkmenistan_Ashgabat.csv as Turkmenistan_Ashgabat.csv
# Saved dataset for Türkiye_Adana.csv as Türkiye_Adana.csv
# Saved dataset for Türkiye_Adapazarı.csv as Türkiye_Adapazarı.csv
# Saved dataset for Türkiye_Ankara.csv as Türkiye_Ankara.csv
# Saved dataset for Türkiye_Antakya.csv as Türkiye_Antakya.csv
# Saved dataset for Türkiye_Balıkesir.csv as Türkiye_Balıkesir.csv
# Saved dataset for Türkiye_Bursa.csv as Türkiye_Bursa.csv
# Saved dataset for Türkiye_Denizli.csv as Türkiye_Denizli.csv
# Saved dataset for Türkiye_Erzurum.csv as Türkiye_Erzurum.csv
# Saved dataset for Türkiye_Eskişehir.csv as Türkiye_Eskişehir.csv
# Saved dataset for Türkiye_Istanbul.csv as Türkiye_Istanbul.csv
# Saved dataset for Türkiye_Kayseri.csv as Türkiye_Kayseri.csv
# Saved dataset for Türkiye_Konya.csv as Türkiye_Konya.csv
# Saved dataset for Türkiye_Kütahya.csv as Türkiye_Kütahya.csv
# Saved dataset for Türkiye_Samsun.csv as Türkiye_Samsun.csv
# Saved dataset for Türkiye_Sivas.csv as Türkiye_Sivas.csv
# Saved dataset for Türkiye_Trabzon.csv as Türkiye_Trabzon.csv
# Saved dataset for Türkiye_İzmir.csv as Türkiye_İzmir.csv
# Saved dataset for Türkiye_İzmit.csv as Türkiye_İzmit.csv
# Saved dataset for Uganda_Kampala.csv as Uganda_Kampala.csv
# Saved dataset for Ukraine_Dnipro.csv as Ukraine_Dnipro.csv
# Saved dataset for Ukraine_Ivano-Frankivsk.csv as Ukraine_Ivano-Frankivsk.csv
# Saved dataset for Ukraine_Kamianske.csv as Ukraine_Kamianske.csv
# Saved dataset for Ukraine_Kryvyi Rih.csv as Ukraine_Kryvyi Rih.csv
# Saved dataset for Ukraine_Kyiv.csv as Ukraine_Kyiv.csv
# Saved dataset for Ukraine_Lviv.csv as Ukraine_Lviv.csv
# Saved dataset for Ukraine_Odessa.csv as Ukraine_Odessa.csv
# Saved dataset for Ukraine_Ternopil.csv as Ukraine_Ternopil.csv
# Saved dataset for Ukraine_Zaporizhia.csv as Ukraine_Zaporizhia.csv
# Saved dataset for United Arab Emirates_Abu Dhabi.csv as United Arab Emirates_Abu Dhabi.csv
# Saved dataset for United Arab Emirates_Dubai.csv as United Arab Emirates_Dubai.csv
# Saved dataset for United Kingdom_Belfast.csv as United Kingdom_Belfast.csv
# Saved dataset for United Kingdom_Birmingham.csv as United Kingdom_Birmingham.csv
# Saved dataset for United Kingdom_Bristol.csv as United Kingdom_Bristol.csv
# Saved dataset for United Kingdom_Cardiff.csv as United Kingdom_Cardiff.csv
# Saved dataset for United Kingdom_Coventry.csv as United Kingdom_Coventry.csv
# Saved dataset for United Kingdom_Edinburgh.csv as United Kingdom_Edinburgh.csv
# Saved dataset for United Kingdom_Glasgow.csv as United Kingdom_Glasgow.csv
# Saved dataset for United Kingdom_Leeds.csv as United Kingdom_Leeds.csv
# Saved dataset for United Kingdom_Leicester.csv as United Kingdom_Leicester.csv
# Saved dataset for United Kingdom_Liverpool.csv as United Kingdom_Liverpool.csv
# Saved dataset for United Kingdom_London.csv as United Kingdom_London.csv
# Saved dataset for United Kingdom_Luton.csv as United Kingdom_Luton.csv
# Saved dataset for United Kingdom_Manchester.csv as United Kingdom_Manchester.csv
# Saved dataset for United Kingdom_Newport.csv as United Kingdom_Newport.csv
# Saved dataset for United Kingdom_Norwich.csv as United Kingdom_Norwich.csv
# Saved dataset for United Kingdom_Plymouth.csv as United Kingdom_Plymouth.csv
# Saved dataset for United Kingdom_Preston.csv as United Kingdom_Preston.csv
# Saved dataset for United Kingdom_Reading.csv as United Kingdom_Reading.csv
# Saved dataset for United Kingdom_Sheffield.csv as United Kingdom_Sheffield.csv
# Saved dataset for United Kingdom_Southend-on-Sea.csv as United Kingdom_Southend-on-Sea.csv
# Saved dataset for United Kingdom_Swansea.csv as United Kingdom_Swansea.csv
# Saved dataset for United States_Albuquerque.csv as United States_Albuquerque.csv
# Saved dataset for United States_Atlanta.csv as United States_Atlanta.csv
# Saved dataset for United States_Austin.csv as United States_Austin.csv
# Saved dataset for United States_Baltimore.csv as United States_Baltimore.csv
# Saved dataset for United States_Boise.csv as United States_Boise.csv
# Saved dataset for United States_Boston.csv as United States_Boston.csv
# Saved dataset for United States_Brooklyn.csv as United States_Brooklyn.csv
# Saved dataset for United States_Charlotte.csv as United States_Charlotte.csv
# Saved dataset for United States_Chicago.csv as United States_Chicago.csv
# Saved dataset for United States_Columbia.csv as United States_Columbia.csv
# Saved dataset for United States_Columbus.csv as United States_Columbus.csv
# Saved dataset for United States_Dallas.csv as United States_Dallas.csv
# Saved dataset for United States_Denver.csv as United States_Denver.csv
# Saved dataset for United States_Detroit.csv as United States_Detroit.csv
# Saved dataset for United States_El Paso.csv as United States_El Paso.csv
# Saved dataset for United States_Fort Worth.csv as United States_Fort Worth.csv
# Saved dataset for United States_Fresno.csv as United States_Fresno.csv
# Saved dataset for United States_Hartford.csv as United States_Hartford.csv
# Saved dataset for United States_Honolulu.csv as United States_Honolulu.csv
# Saved dataset for United States_Houston.csv as United States_Houston.csv
# Saved dataset for United States_Indianapolis.csv as United States_Indianapolis.csv
# Saved dataset for United States_Jackson.csv as United States_Jackson.csv
# Saved dataset for United States_Jacksonville.csv as United States_Jacksonville.csv
# Saved dataset for United States_Las Vegas.csv as United States_Las Vegas.csv
# Saved dataset for United States_Little Rock.csv as United States_Little Rock.csv
# Saved dataset for United States_Los Angeles.csv as United States_Los Angeles.csv
# Saved dataset for United States_Madison.csv as United States_Madison.csv
# Saved dataset for United States_Manhattan.csv as United States_Manhattan.csv
# Saved dataset for United States_Memphis.csv as United States_Memphis.csv
# Saved dataset for United States_Miami.csv as United States_Miami.csv
# Saved dataset for United States_Milwaukee.csv as United States_Milwaukee.csv
# Saved dataset for United States_Nashville.csv as United States_Nashville.csv
# Saved dataset for United States_Oakland.csv as United States_Oakland.csv
# Saved dataset for United States_Oklahoma City.csv as United States_Oklahoma City.csv
# Saved dataset for United States_Omaha.csv as United States_Omaha.csv
# Saved dataset for United States_Philadelphia.csv as United States_Philadelphia.csv
# Saved dataset for United States_Phoenix.csv as United States_Phoenix.csv
# Saved dataset for United States_Portland.csv as United States_Portland.csv
# Saved dataset for United States_Providence.csv as United States_Providence.csv
# Saved dataset for United States_Queens.csv as United States_Queens.csv
# Saved dataset for United States_Raleigh.csv as United States_Raleigh.csv
# Saved dataset for United States_Richmond.csv as United States_Richmond.csv
# Saved dataset for United States_Sacramento.csv as United States_Sacramento.csv
# Saved dataset for United States_Saint Paul.csv as United States_Saint Paul.csv
# Saved dataset for United States_Salem.csv as United States_Salem.csv
# Saved dataset for United States_Salt Lake City.csv as United States_Salt Lake City.csv
# Saved dataset for United States_San Antonio.csv as United States_San Antonio.csv
# Saved dataset for United States_San Diego.csv as United States_San Diego.csv
# Saved dataset for United States_San Francisco.csv as United States_San Francisco.csv
# Saved dataset for United States_San Jose.csv as United States_San Jose.csv
# Saved dataset for United States_Seattle.csv as United States_Seattle.csv
# Saved dataset for United States_Springfield.csv as United States_Springfield.csv
# Saved dataset for United States_Staten Island.csv as United States_Staten Island.csv
# Saved dataset for United States_Tallahassee.csv as United States_Tallahassee.csv
# Saved dataset for United States_The Bronx.csv as United States_The Bronx.csv
# Saved dataset for United States_Tucson.csv as United States_Tucson.csv
# Saved dataset for United States_Washington D.C..csv as United States_Washington D.C..csv
# Saved dataset for Uzbekistan_Tashkent.csv as Uzbekistan_Tashkent.csv
# Saved dataset for Vietnam_Haiphong.csv as Vietnam_Haiphong.csv
# Saved dataset for Vietnam_Hanoi.csv as Vietnam_Hanoi.csv
# Saved dataset for Vietnam_Ho Chi Minh City.csv as Vietnam_Ho Chi Minh City.csv
# Saved dataset for Vietnam_Huế.csv as Vietnam_Huế.csv
# Saved dataset for Vietnam_Hạ Long.csv as Vietnam_Hạ Long.csv

# %%
# Compress all CSV files present in the working directory
# !zip -r /kaggle/working/all_csvs.zip /kaggle/working/*.csv
# Out:
#   adding: kaggle/working/Afghanistan_Kabul.csv (deflated 84%)
#   adding: kaggle/working/Algeria_Algiers.csv (deflated 83%)
#   adding: kaggle/working/Argentina_Buenos Aires.csv (deflated 79%)
#   adding: kaggle/working/Australia_Adelaide.csv (deflated 80%)
#   adding: kaggle/working/Australia_Brisbane.csv (deflated 81%)
#   adding: kaggle/working/Australia_Canberra.csv (deflated 78%)
#   adding: kaggle/working/Australia_Darwin.csv (deflated 78%)
#   adding: kaggle/working/Australia_Hobart.csv (deflated 82%)
#   adding: kaggle/working/Australia_Launceston.csv (deflated 83%)
#   adding: kaggle/working/Australia_Melbourne.csv (deflated 79%)
#   adding: kaggle/working/Australia_Newcastle.csv (deflated 80%)
#   adding: kaggle/working/Australia_Perth.csv (deflated 80%)
#   adding: kaggle/working/Australia_Sydney.csv (deflated 80%)
#   adding: kaggle/working/Australia_Wollongong.csv (deflated 80%)
#   adding: kaggle/working/Austria_Graz.csv (deflated 80%)
#   adding: kaggle/working/Austria_Innsbruck.csv (deflated 81%)
#   adding: kaggle/working/Austria_Linz.csv (deflated 79%)
#   adding: kaggle/working/Austria_Salzburg.csv (deflated 82%)
#   adding: kaggle/working/Austria_Vienna.csv (deflated 80%)
#   adding: kaggle/working/Bahrain_Manama.csv (deflated 81%)
#   adding: kaggle/working/Bangladesh_Dhaka.csv (deflated 85%)
#   adding: kaggle/working/Belgium_Antwerpen.csv (deflated 79%)
#   adding: kaggle/working/Belgium_Brussels.csv (deflated 80%)
#   adding: kaggle/working/Belgium_Charleroi.csv (deflated 80%)
#   adding: kaggle/working/Belgium_Gent.csv (deflated 78%)
#   adding: kaggle/working/Belgium_Liège.csv (deflated 79%)
#   adding: kaggle/working/Belgium_Namur.csv (deflated 78%)
#   adding: kaggle/working/Bolivia_Cochabamba.csv (deflated 82%)
#   adding: kaggle/working/Bosnia and Herzegovina_Sarajevo.csv (deflated 81%)
#   adding: kaggle/working/Bosnia and Herzegovina_Tuzla.csv (deflated 81%)
#   adding: kaggle/working/Bosnia and Herzegovina_Zenica.csv (deflated 80%)
#   adding: kaggle/working/Brazil_São José dos Campos.csv (deflated 85%)
#   adding: kaggle/working/Brazil_São Paulo.csv (deflated 80%)
#   adding: kaggle/working/Brazil_Vitória.csv (deflated 76%)
#   adding: kaggle/working/Bulgaria_Burgas.csv (deflated 79%)
#   adding: kaggle/working/Bulgaria_Plovdiv.csv (deflated 78%)
#   adding: kaggle/working/Bulgaria_Sofia.csv (deflated 78%)
#   adding: kaggle/working/Canada_Calgary.csv (deflated 79%)
#   adding: kaggle/working/Canada_Edmonton.csv (deflated 80%)
#   adding: kaggle/working/Canada_Halifax.csv (deflated 78%)
#   adding: kaggle/working/Canada_Hamilton.csv (deflated 78%)
#   adding: kaggle/working/Canada_Kitchener.csv (deflated 78%)
#   adding: kaggle/working/Canada_London.csv (deflated 79%)
#   adding: kaggle/working/Canada_Mississauga.csv (deflated 79%)
#   adding: kaggle/working/Canada_Montréal.csv (deflated 81%)
#   adding: kaggle/working/Canada_Ottawa.csv (deflated 78%)
#   adding: kaggle/working/Canada_Québec.csv (deflated 80%)
#   adding: kaggle/working/Canada_Surrey.csv (deflated 78%)
#   adding: kaggle/working/Canada_Toronto.csv (deflated 78%)
#   adding: kaggle/working/Canada_Vancouver.csv (deflated 80%)
#   adding: kaggle/working/Canada_Victoria.csv (deflated 80%)
#   adding: kaggle/working/Canada_Winnipeg.csv (deflated 78%)
#   adding: kaggle/working/Chile_Calama.csv (deflated 78%)
#   adding: kaggle/working/Chile_Chillán.csv (deflated 84%)
#   adding: kaggle/working/Chile_Concepción.csv (deflated 80%)
#   adding: kaggle/working/Chile_Los Ángeles.csv (deflated 85%)
#   adding: kaggle/working/Chile_Osorno.csv (deflated 82%)
#   adding: kaggle/working/Chile_Puerto Montt.csv (deflated 85%)
#   adding: kaggle/working/Chile_Quilpué.csv (deflated 79%)
#   adding: kaggle/working/Chile_Rancagua.csv (deflated 79%)
#   adding: kaggle/working/Chile_Santiago.csv (deflated 78%)
#   adding: kaggle/working/Chile_Talca.csv (deflated 78%)
#   adding: kaggle/working/Chile_Temuco.csv (deflated 77%)
#   adding: kaggle/working/Chile_Valparaíso.csv (deflated 85%)
#   adding: kaggle/working/China_Anyang.csv (deflated 75%)
#   adding: kaggle/working/China_Beijing.csv (deflated 77%)
#   adding: kaggle/working/China_Changchun.csv (deflated 79%)
#   adding: kaggle/working/China_Changsha.csv (deflated 79%)
#   adding: kaggle/working/China_Changzhou.csv (deflated 78%)
#   adding: kaggle/working/China_Chengdu.csv (deflated 79%)
#   adding: kaggle/working/China_Chongqing.csv (deflated 80%)
#   adding: kaggle/working/China_Dongguan.csv (deflated 80%)
#   adding: kaggle/working/China_Foshan.csv (deflated 77%)
#   adding: kaggle/working/China_Fushun.csv (deflated 77%)
#   adding: kaggle/working/China_Fuzhou.csv (deflated 79%)
#   adding: kaggle/working/China_Guangzhou.csv (deflated 79%)
#   adding: kaggle/working/China_Guiyang.csv (deflated 80%)
#   adding: kaggle/working/China_Haikou.csv (deflated 81%)
#   adding: kaggle/working/China_Hangzhou.csv (deflated 79%)
#   adding: kaggle/working/China_Harbin.csv (deflated 77%)
#   adding: kaggle/working/China_Hefei.csv (deflated 78%)
#   adding: kaggle/working/China_Hegang.csv (deflated 76%)
#   adding: kaggle/working/China_Hohhot.csv (deflated 79%)
#   adding: kaggle/working/China_Jieyang.csv (deflated 80%)
#   adding: kaggle/working/China_Jinan.csv (deflated 76%)
#   adding: kaggle/working/China_Kunming.csv (deflated 80%)
#   adding: kaggle/working/China_Lanzhou.csv (deflated 78%)
#   adding: kaggle/working/China_Lhasa.csv (deflated 79%)
#   adding: kaggle/working/China_Nanchang.csv (deflated 77%)
#   adding: kaggle/working/China_Nanjing.csv (deflated 79%)
#   adding: kaggle/working/China_Nanning.csv (deflated 80%)
#   adding: kaggle/working/China_Ningbo.csv (deflated 79%)
#   adding: kaggle/working/China_Qingdao.csv (deflated 79%)
#   adding: kaggle/working/China_Qinhuangdao.csv (deflated 77%)
#   adding: kaggle/working/China_Qiqihar.csv (deflated 77%)
#   adding: kaggle/working/China_Shanghai.csv (deflated 77%)
#   adding: kaggle/working/China_Shantou.csv (deflated 80%)
#   adding: kaggle/working/China_Shenyang.csv (deflated 77%)
#   adding: kaggle/working/China_Shenzhen.csv (deflated 78%)
#   adding: kaggle/working/China_Shijiazhuang.csv (deflated 79%)
#   adding: kaggle/working/China_Shiyan.csv (deflated 77%)
#   adding: kaggle/working/China_Suzhou.csv (deflated 78%)
#   adding: kaggle/working/China_Taiyuan.csv (deflated 77%)
#   adding: kaggle/working/China_Tianjin.csv (deflated 78%)
#   adding: kaggle/working/China_Ürümqi.csv (deflated 78%)
#   adding: kaggle/working/China_Wuhan.csv (deflated 78%)
#   adding: kaggle/working/China_Wuxi.csv (deflated 76%)
#   adding: kaggle/working/China_Xiamen.csv (deflated 80%)
#   adding: kaggle/working/China_Xi’an.csv (deflated 78%)
#   adding: kaggle/working/China_Xining.csv (deflated 76%)
#   adding: kaggle/working/China_Xinxiang.csv (deflated 78%)
#   adding: kaggle/working/China_Xuchang.csv (deflated 78%)
#   adding: kaggle/working/China_Yinchuan.csv (deflated 77%)
#   adding: kaggle/working/China_Yunfu.csv (deflated 77%)
#   adding: kaggle/working/China_Zhengzhou.csv (deflated 78%)
#   adding: kaggle/working/China_Zhuzhou.csv (deflated 79%)
#   adding: kaggle/working/Colombia_Bogotá.csv (deflated 80%)
#   adding: kaggle/working/Colombia_Medellín.csv (deflated 80%)
#   adding: kaggle/working/Costa Rica_San José.csv (deflated 83%)
#   adding: kaggle/working/Croatia_Rijeka.csv (deflated 76%)
#   adding: kaggle/working/Croatia_Split.csv (deflated 81%)
#   adding: kaggle/working/Croatia_Zagreb.csv (deflated 77%)
#   adding: kaggle/working/Curaçao_Willemstad.csv (deflated 88%)
#   adding: kaggle/working/Cyprus_Limassol.csv (deflated 78%)
#   adding: kaggle/working/Cyprus_Nicosia.csv (deflated 78%)
#   adding: kaggle/working/Czechia_Brno.csv (deflated 76%)
#   adding: kaggle/working/Czechia_Olomouc.csv (deflated 77%)
#   adding: kaggle/working/Czechia_Ostrava.csv (deflated 77%)
#   adding: kaggle/working/Czechia_Pilsen.csv (deflated 77%)
#   adding: kaggle/working/Czechia_Prague.csv (deflated 77%)
#   adding: kaggle/working/Denmark_Copenhagen.csv (deflated 77%)
#   adding: kaggle/working/Ecuador_Quito.csv (deflated 78%)
#   adding: kaggle/working/El Salvador_San Salvador.csv (deflated 85%)
#   adding: kaggle/working/Estonia_Tallinn.csv (deflated 77%)
#   adding: kaggle/working/Ethiopia_Addis Ababa.csv (deflated 87%)
#   adding: kaggle/working/Finland_Helsinki.csv (deflated 77%)
#   adding: kaggle/working/Finland_Oulu.csv (deflated 77%)
#   adding: kaggle/working/Finland_Tampere.csv (deflated 80%)
#   adding: kaggle/working/Finland_Turku.csv (deflated 80%)
#   adding: kaggle/working/Finland_Vantaa.csv (deflated 79%)
#   adding: kaggle/working/France_Amiens.csv (deflated 77%)
#   adding: kaggle/working/France_Besançon.csv (deflated 78%)
#   adding: kaggle/working/France_Bordeaux.csv (deflated 79%)
#   adding: kaggle/working/France_Caen.csv (deflated 79%)
#   adding: kaggle/working/France_Clermont-Ferrand.csv (deflated 81%)
#   adding: kaggle/working/France_Dijon.csv (deflated 77%)
#   adding: kaggle/working/France_Grenoble.csv (deflated 77%)
#   adding: kaggle/working/France_Lille.csv (deflated 77%)
#   adding: kaggle/working/France_Limoges.csv (deflated 80%)
#   adding: kaggle/working/France_Lyon.csv (deflated 77%)
#   adding: kaggle/working/France_Marseille.csv (deflated 78%)
#   adding: kaggle/working/France_Metz.csv (deflated 77%)
#   adding: kaggle/working/France_Montpellier.csv (deflated 79%)
#   adding: kaggle/working/France_Nancy.csv (deflated 78%)
#   adding: kaggle/working/France_Nantes.csv (deflated 79%)
#   adding: kaggle/working/France_Nice.csv (deflated 77%)
#   adding: kaggle/working/France_Nîmes.csv (deflated 78%)
#   adding: kaggle/working/France_Orléans.csv (deflated 78%)
#   adding: kaggle/working/France_Paris.csv (deflated 76%)
#   adding: kaggle/working/France_Perpignan.csv (deflated 78%)
#   adding: kaggle/working/France_Rennes.csv (deflated 79%)
#   adding: kaggle/working/France_Rouen.csv (deflated 78%)
#   adding: kaggle/working/France_Saint-Étienne.csv (deflated 81%)
#   adding: kaggle/working/France_Strasbourg.csv (deflated 80%)
#   adding: kaggle/working/France_Toulon.csv (deflated 77%)
#   adding: kaggle/working/France_Toulouse.csv (deflated 78%)
#   adding: kaggle/working/France_Tours.csv (deflated 78%)
#   adding: kaggle/working/Georgia_Tbilisi.csv (deflated 76%)
#   adding: kaggle/working/Germany_Augsburg.csv (deflated 80%)
#   adding: kaggle/working/Germany_Berlin.csv (deflated 77%)
#   adding: kaggle/working/Germany_Darmstadt.csv (deflated 78%)
#   adding: kaggle/working/Germany_Dresden.csv (deflated 78%)
#   adding: kaggle/working/Germany_Düsseldorf.csv (deflated 79%)
#   adding: kaggle/working/Germany_Freiburg.csv (deflated 78%)
#   adding: kaggle/working/Germany_Hamburg.csv (deflated 80%)
#   adding: kaggle/working/Germany_Hannover.csv (deflated 79%)
#   adding: kaggle/working/Germany_Karlsruhe.csv (deflated 79%)
#   adding: kaggle/working/Germany_Kassel.csv (deflated 78%)
#   adding: kaggle/working/Germany_Köln.csv (deflated 78%)
#   adding: kaggle/working/Germany_Mainz.csv (deflated 80%)
#   adding: kaggle/working/Germany_Munich.csv (deflated 78%)
#   adding: kaggle/working/Germany_Münster.csv (deflated 79%)
#   adding: kaggle/working/Germany_Potsdam.csv (deflated 78%)
#   adding: kaggle/working/Germany_Stuttgart.csv (deflated 79%)
#   adding: kaggle/working/Germany_Wiesbaden.csv (deflated 79%)
#   adding: kaggle/working/Ghana_Accra.csv (deflated 87%)
#   adding: kaggle/working/Greece_Athens.csv (deflated 76%)
#   adding: kaggle/working/Greece_Thessaloníki.csv (deflated 77%)
#   adding: kaggle/working/Guatemala_Guatemala City.csv (deflated 87%)
#   adding: kaggle/working/Guinea_Conakry.csv (deflated 84%)
#   adding: kaggle/working/Hong Kong_Hong Kong.csv (deflated 78%)
#   adding: kaggle/working/Hungary_Budapest.csv (deflated 76%)
#   adding: kaggle/working/Hungary_Debrecen.csv (deflated 77%)
#   adding: kaggle/working/Hungary_Győr.csv (deflated 76%)
#   adding: kaggle/working/Hungary_Kecskemét.csv (deflated 77%)
#   adding: kaggle/working/Hungary_Miskolc.csv (deflated 76%)
#   adding: kaggle/working/Hungary_Pécs.csv (deflated 76%)
#   adding: kaggle/working/Hungary_Szeged.csv (deflated 76%)
#   adding: kaggle/working/Iceland_Reykjavík.csv (deflated 81%)
#   adding: kaggle/working/India_Bengaluru.csv (deflated 77%)
#   adding: kaggle/working/India_Bhopal.csv (deflated 74%)
#   adding: kaggle/working/India_Chandigarh.csv (deflated 76%)
#   adding: kaggle/working/India_Chennai.csv (deflated 77%)
#   adding: kaggle/working/India_Delhi.csv (deflated 74%)
#   adding: kaggle/working/India_Gandhinagar.csv (deflated 76%)
#   adding: kaggle/working/India_Ghāziābād.csv (deflated 76%)
#   adding: kaggle/working/India_Hāpur.csv (deflated 74%)
#   adding: kaggle/working/India_Hyderabad.csv (deflated 78%)
#   adding: kaggle/working/India_Jaipur.csv (deflated 75%)
#   adding: kaggle/working/India_Kolkata.csv (deflated 76%)
#   adding: kaggle/working/India_Lucknow.csv (deflated 76%)
#   adding: kaggle/working/India_Mumbai.csv (deflated 76%)
#   adding: kaggle/working/India_Muzaffarnagar.csv (deflated 77%)
#   adding: kaggle/working/India_Mysore.csv (deflated 76%)
#   adding: kaggle/working/India_Nagpur.csv (deflated 75%)
#   adding: kaggle/working/India_Nashik.csv (deflated 75%)
#   adding: kaggle/working/India_New Delhi.csv (deflated 84%)
#   adding: kaggle/working/India_Patna.csv (deflated 76%)
#   adding: kaggle/working/India_Shillong.csv (deflated 75%)
#   adding: kaggle/working/India_Thiruvananthapuram.csv (deflated 80%)
#   adding: kaggle/working/India_Thrissur.csv (deflated 78%)
#   adding: kaggle/working/India_Visakhapatnam.csv (deflated 77%)
#   adding: kaggle/working/Indonesia_Jakarta.csv (deflated 83%)
#   adding: kaggle/working/Iran_Arāk.csv (deflated 77%)
#   adding: kaggle/working/Iran_Bandar Abbas.csv (deflated 81%)
#   adding: kaggle/working/Iran_Īlām.csv (deflated 83%)
#   adding: kaggle/working/Iran_Isfahan.csv (deflated 81%)
#   adding: kaggle/working/Iran_Karaj.csv (deflated 78%)
#   adding: kaggle/working/Iran_Kerman.csv (deflated 80%)
#   adding: kaggle/working/Iran_Kermanshah.csv (deflated 80%)
#   adding: kaggle/working/Iran_Khorramabad.csv (deflated 81%)
#   adding: kaggle/working/Iran_Khorramshahr.csv (deflated 82%)
#   adding: kaggle/working/Iran_Mashhad.csv (deflated 79%)
#   adding: kaggle/working/Iran_Orūmīyeh.csv (deflated 80%)
#   adding: kaggle/working/Iran_Qom.csv (deflated 78%)
#   adding: kaggle/working/Iran_Sanandaj.csv (deflated 80%)
#   adding: kaggle/working/Iran_Shiraz.csv (deflated 80%)
#   adding: kaggle/working/Iran_Tabriz.csv (deflated 79%)
#   adding: kaggle/working/Iran_Tehran.csv (deflated 78%)
#   adding: kaggle/working/Iran_Yazd.csv (deflated 79%)
#   adding: kaggle/working/Iran_Zanjān.csv (deflated 80%)
#   adding: kaggle/working/Iraq_Baghdad.csv (deflated 82%)
#   adding: kaggle/working/Ireland_Dublin.csv (deflated 75%)
#   adding: kaggle/working/Israel_Ashdod.csv (deflated 76%)
#   adding: kaggle/working/Israel_Ashkelon.csv (deflated 77%)
#   adding: kaggle/working/Israel_Haifa.csv (deflated 76%)
#   adding: kaggle/working/Israel_Jerusalem.csv (deflated 77%)
#   adding: kaggle/working/Israel_Netanya.csv (deflated 77%)
#   adding: kaggle/working/Israel_Petaẖ Tiqwa.csv (deflated 80%)
#   adding: kaggle/working/Israel_Tel Aviv.csv (deflated 77%)
#   adding: kaggle/working/Italy_Bologna.csv (deflated 78%)
#   adding: kaggle/working/Italy_Brescia.csv (deflated 77%)
#   adding: kaggle/working/Italy_Florence.csv (deflated 78%)
#   adding: kaggle/working/Italy_Livorno.csv (deflated 79%)
#   adding: kaggle/working/Italy_Milan.csv (deflated 77%)
#   adding: kaggle/working/Italy_Modena.csv (deflated 77%)
#   adding: kaggle/working/Italy_Naples.csv (deflated 75%)
#   adding: kaggle/working/Italy_Parma.csv (deflated 77%)
#   adding: kaggle/working/Italy_Prato.csv (deflated 77%)
#   adding: kaggle/working/Italy_Rome.csv (deflated 77%)
#   adding: kaggle/working/Italy_Trieste.csv (deflated 79%)
#   adding: kaggle/working/Italy_Turin.csv (deflated 80%)
#   adding: kaggle/working/Ivory Coast_Abidjan.csv (deflated 87%)
#   adding: kaggle/working/Japan_Akita.csv (deflated 79%)
#   adding: kaggle/working/Japan_Chiba.csv (deflated 79%)
#   adding: kaggle/working/Japan_Fukuoka.csv (deflated 80%)
#   adding: kaggle/working/Japan_Gifu-shi.csv (deflated 79%)
#   adding: kaggle/working/Japan_Hiroshima.csv (deflated 80%)
#   adding: kaggle/working/Japan_Kagoshima.csv (deflated 80%)
#   adding: kaggle/working/Japan_Kanazawa.csv (deflated 80%)
#   adding: kaggle/working/Japan_Kobe.csv (deflated 78%)
#   adding: kaggle/working/Japan_Kochi.csv (deflated 80%)
#   adding: kaggle/working/Japan_Kumamoto.csv (deflated 80%)
#   adding: kaggle/working/Japan_Kyoto.csv (deflated 79%)
#   adding: kaggle/working/Japan_Matsuyama.csv (deflated 80%)
#   adding: kaggle/working/Japan_Miyazaki.csv (deflated 80%)
#   adding: kaggle/working/Japan_Nagano.csv (deflated 79%)
#   adding: kaggle/working/Japan_Nagasaki.csv (deflated 80%)
#   adding: kaggle/working/Japan_Nagoya.csv (deflated 80%)
#   adding: kaggle/working/Japan_Naha.csv (deflated 80%)
#   adding: kaggle/working/Japan_Nara-shi.csv (deflated 80%)
#   adding: kaggle/working/Japan_Niigata.csv (deflated 80%)
#   adding: kaggle/working/Japan_Ōita.csv (deflated 79%)
#   adding: kaggle/working/Japan_Okayama.csv (deflated 79%)
#   adding: kaggle/working/Japan_Osaka.csv (deflated 79%)
#   adding: kaggle/working/Japan_Saitama.csv (deflated 80%)
#   adding: kaggle/working/Japan_Sapporo.csv (deflated 80%)
#   adding: kaggle/working/Japan_Sendai.csv (deflated 79%)
#   adding: kaggle/working/Japan_Shizuoka.csv (deflated 80%)
#   adding: kaggle/working/Japan_Takamatsu.csv (deflated 80%)
#   adding: kaggle/working/Japan_Tokyo.csv (deflated 79%)
#   adding: kaggle/working/Japan_Toyama.csv (deflated 80%)
#   adding: kaggle/working/Japan_Utsunomiya.csv (deflated 81%)
#   adding: kaggle/working/Japan_Wakayama.csv (deflated 80%)
#   adding: kaggle/working/Japan_Yokohama.csv (deflated 79%)
#   adding: kaggle/working/Jordan_Amman.csv (deflated 77%)
#   adding: kaggle/working/Jordan_Irbid.csv (deflated 76%)
#   adding: kaggle/working/Jordan_Zarqa.csv (deflated 77%)
#   adding: kaggle/working/Kazakhstan_Almaty.csv (deflated 79%)
#   adding: kaggle/working/Kazakhstan_Nur-Sultan.csv (deflated 80%)
#   adding: kaggle/working/Kosovo_Pristina.csv (deflated 77%)
#   adding: kaggle/working/Kuwait_Ḩawallī.csv (deflated 78%)
#   adding: kaggle/working/Kyrgyzstan_Bishkek.csv (deflated 83%)
#   adding: kaggle/working/Laos_Vientiane.csv (deflated 83%)
#   adding: kaggle/working/Lithuania_Kaunas.csv (deflated 79%)
#   adding: kaggle/working/Macao_Macau.csv (deflated 77%)
#   adding: kaggle/working/Mali_Bamako.csv (deflated 82%)
#   adding: kaggle/working/Mexico_Aguascalientes.csv (deflated 79%)
#   adding: kaggle/working/Mexico_Chihuahua.csv (deflated 79%)
#   adding: kaggle/working/Mexico_Cuernavaca.csv (deflated 78%)
#   adding: kaggle/working/Mexico_Ecatepec de Morelos.csv (deflated 82%)
#   adding: kaggle/working/Mexico_Guadalajara.csv (deflated 78%)
#   adding: kaggle/working/Mexico_Mérida.csv (deflated 78%)
#   adding: kaggle/working/Mexico_Mexico City.csv (deflated 80%)
#   adding: kaggle/working/Mexico_Monterrey.csv (deflated 79%)
#   adding: kaggle/working/Mexico_Morelia.csv (deflated 76%)
#   adding: kaggle/working/Mexico_Oaxaca.csv (deflated 79%)
#   adding: kaggle/working/Mexico_Pachuca de Soto.csv (deflated 80%)
#   adding: kaggle/working/Mexico_Puebla.csv (deflated 76%)
#   adding: kaggle/working/Mexico_San Luis Potosí.csv (deflated 81%)
#   adding: kaggle/working/Mexico_Tepic.csv (deflated 76%)
#   adding: kaggle/working/Mexico_Toluca.csv (deflated 79%)
#   adding: kaggle/working/Mongolia_Ulan Bator.csv (deflated 78%)
#   adding: kaggle/working/Myanmar_Yangon.csv (deflated 85%)
#   adding: kaggle/working/Nepal_Biratnagar.csv (deflated 79%)
#   adding: kaggle/working/Nepal_Kathmandu.csv (deflated 82%)
#   adding: kaggle/working/Nepal_Pokhara.csv (deflated 78%)
#   adding: kaggle/working/New Zealand_Auckland.csv (deflated 81%)
#   adding: kaggle/working/New Zealand_Christchurch.csv (deflated 80%)
#   adding: kaggle/working/New Zealand_Dunedin.csv (deflated 81%)
#   adding: kaggle/working/New Zealand_Hamilton.csv (deflated 81%)
#   adding: kaggle/working/New Zealand_Wellington.csv (deflated 83%)
#   adding: kaggle/working/North Macedonia_Skopje.csv (deflated 79%)
#   adding: kaggle/working/Norway_Bergen.csv (deflated 78%)
#   adding: kaggle/working/Norway_Oslo.csv (deflated 77%)
#   adding: kaggle/working/Norway_Stavanger.csv (deflated 79%)
#   adding: kaggle/working/Norway_Trondheim.csv (deflated 79%)
#   adding: kaggle/working/Pakistan_Islamabad.csv (deflated 80%)
#   adding: kaggle/working/Pakistan_Karachi.csv (deflated 83%)
#   adding: kaggle/working/Pakistan_Lahore.csv (deflated 82%)
#   adding: kaggle/working/Pakistan_Peshawar.csv (deflated 85%)
#   adding: kaggle/working/Peru_Lima.csv (deflated 75%)
#   adding: kaggle/working/Philippines_Baguio.csv (deflated 82%)
#   adding: kaggle/working/Philippines_Butuan.csv (deflated 82%)
#   adding: kaggle/working/Philippines_Manila.csv (deflated 79%)
#   adding: kaggle/working/Philippines_Zamboanga.csv (deflated 86%)
#   adding: kaggle/working/Poland_Bydgoszcz.csv (deflated 77%)
#   adding: kaggle/working/Poland_Gdańsk.csv (deflated 77%)
#   adding: kaggle/working/Poland_Katowice.csv (deflated 76%)
#   adding: kaggle/working/Poland_Kielce.csv (deflated 76%)
#   adding: kaggle/working/Poland_Kraków.csv (deflated 76%)
#   adding: kaggle/working/Poland_Łódź.csv (deflated 75%)
#   adding: kaggle/working/Poland_Płock.csv (deflated 76%)
#   adding: kaggle/working/Poland_Poznań.csv (deflated 76%)
#   adding: kaggle/working/Poland_Rybnik.csv (deflated 76%)
#   adding: kaggle/working/Poland_Szczecin.csv (deflated 77%)
#   adding: kaggle/working/Poland_Tarnów.csv (deflated 75%)
#   adding: kaggle/working/Poland_Warsaw.csv (deflated 75%)
#   adding: kaggle/working/Poland_Wrocław.csv (deflated 75%)
#   adding: kaggle/working/Poland_Zabrze.csv (deflated 76%)
#   adding: kaggle/working/Portugal_Funchal.csv (deflated 78%)
#   adding: kaggle/working/Portugal_Lisbon.csv (deflated 79%)
#   adding: kaggle/working/Puerto Rico_San Juan.csv (deflated 82%)
#   adding: kaggle/working/Réunion_Saint-Denis.csv (deflated 81%)
#   adding: kaggle/working/Romania_Arad.csv (deflated 76%)
#   adding: kaggle/working/Romania_Bacău.csv (deflated 78%)
#   adding: kaggle/working/Romania_Baia Mare.csv (deflated 78%)
#   adding: kaggle/working/Romania_Brăila.csv (deflated 77%)
#   adding: kaggle/working/Romania_Braşov.csv (deflated 78%)
#   adding: kaggle/working/Romania_Bucharest.csv (deflated 77%)
#   adding: kaggle/working/Romania_Cluj-Napoca.csv (deflated 80%)
#   adding: kaggle/working/Romania_Constanţa.csv (deflated 79%)
#   adding: kaggle/working/Romania_Craiova.csv (deflated 77%)
#   adding: kaggle/working/Romania_Galaţi.csv (deflated 78%)
#   adding: kaggle/working/Romania_Iaşi.csv (deflated 78%)
#   adding: kaggle/working/Romania_Oradea.csv (deflated 78%)
#   adding: kaggle/working/Romania_Piteşti.csv (deflated 79%)
#   adding: kaggle/working/Romania_Ploieşti.csv (deflated 78%)
#   adding: kaggle/working/Romania_Râmnicu Vâlcea.csv (deflated 81%)
#   adding: kaggle/working/Romania_Sibiu.csv (deflated 77%)
#   adding: kaggle/working/Romania_Timişoara.csv (deflated 79%)
#   adding: kaggle/working/Russia_Chelyabinsk.csv (deflated 77%)
#   adding: kaggle/working/Russia_Krasnoyarsk.csv (deflated 80%)
#   adding: kaggle/working/Russia_Moscow.csv (deflated 76%)
#   adding: kaggle/working/Russia_Nizhniy Novgorod.csv (deflated 76%)
#   adding: kaggle/working/Russia_Novosibirsk.csv (deflated 75%)
#   adding: kaggle/working/Russia_Saint Petersburg.csv (deflated 75%)
#   adding: kaggle/working/Russia_Tomsk.csv (deflated 77%)
#   adding: kaggle/working/Saudi Arabia_Abha.csv (deflated 83%)
#   adding: kaggle/working/Saudi Arabia_Buraydah.csv (deflated 84%)
#   adding: kaggle/working/Saudi Arabia_Dammam.csv (deflated 81%)
#   adding: kaggle/working/Saudi Arabia_Ha'il.csv (deflated 84%)
#   adding: kaggle/working/Saudi Arabia_Jeddah.csv (deflated 83%)
#   adding: kaggle/working/Saudi Arabia_Mecca.csv (deflated 83%)
#   adding: kaggle/working/Saudi Arabia_Riyadh.csv (deflated 83%)
#   adding: kaggle/working/Serbia_Belgrade.csv (deflated 76%)
#   adding: kaggle/working/Serbia_Niš.csv (deflated 75%)
#   adding: kaggle/working/Serbia_Novi Sad.csv (deflated 76%)
#   adding: kaggle/working/Singapore_Singapore.csv (deflated 85%)
#   adding: kaggle/working/Slovakia_Bratislava.csv (deflated 80%)
#   adding: kaggle/working/Slovakia_Košice.csv (deflated 79%)
#   adding: kaggle/working/South Africa_Bloemfontein.csv (deflated 82%)
#   adding: kaggle/working/South Africa_Cape Town.csv (deflated 80%)
#   adding: kaggle/working/South Africa_Durban.csv (deflated 79%)
#   adding: kaggle/working/South Africa_East London.csv (deflated 79%)
#   adding: kaggle/working/South Africa_Johannesburg.csv (deflated 78%)
#   adding: kaggle/working/South Africa_Klerksdorp.csv (deflated 81%)
#   adding: kaggle/working/South Africa_Middelburg.csv (deflated 78%)
#   adding: kaggle/working/South Africa_Port Elizabeth.csv (deflated 81%)
#   adding: kaggle/working/South Africa_Pretoria.csv (deflated 77%)
#   adding: kaggle/working/South Africa_Richards Bay.csv (deflated 83%)
#   adding: kaggle/working/South Africa_Vereeniging.csv (deflated 78%)
#   adding: kaggle/working/South Africa_Worcester.csv (deflated 78%)
#   adding: kaggle/working/South Korea_Andong.csv (deflated 80%)
#   adding: kaggle/working/South Korea_Busan.csv (deflated 80%)
#   adding: kaggle/working/South Korea_Changwon.csv (deflated 81%)
#   adding: kaggle/working/South Korea_Cheongju-si.csv (deflated 81%)
#   adding: kaggle/working/South Korea_Chuncheon.csv (deflated 81%)
#   adding: kaggle/working/South Korea_Daegu.csv (deflated 80%)
#   adding: kaggle/working/South Korea_Daejeon.csv (deflated 80%)
#   adding: kaggle/working/South Korea_Gwangju.csv (deflated 80%)
#   adding: kaggle/working/South Korea_Incheon.csv (deflated 80%)
#   adding: kaggle/working/South Korea_Jeju City.csv (deflated 81%)
#   adding: kaggle/working/South Korea_Jeonju.csv (deflated 81%)
#   adding: kaggle/working/South Korea_Mokpo.csv (deflated 80%)
#   adding: kaggle/working/South Korea_Pohang.csv (deflated 81%)
#   adding: kaggle/working/South Korea_Sejong.csv (deflated 80%)
#   adding: kaggle/working/South Korea_Seongnam-si.csv (deflated 81%)
#   adding: kaggle/working/South Korea_Seoul.csv (deflated 80%)
#   adding: kaggle/working/South Korea_Suncheon.csv (deflated 81%)
#   adding: kaggle/working/South Korea_Suwon.csv (deflated 80%)
#   adding: kaggle/working/South Korea_Ulsan.csv (deflated 80%)
#   adding: kaggle/working/South Korea_Yeosu.csv (deflated 80%)
#   adding: kaggle/working/Spain_Barcelona.csv (deflated 79%)
#   adding: kaggle/working/Spain_Bilbao.csv (deflated 79%)
#   adding: kaggle/working/Spain_Burgos.csv (deflated 79%)
#   adding: kaggle/working/Spain_Castelló de la Plana.csv (deflated 82%)
#   adding: kaggle/working/Spain_Córdoba.csv (deflated 78%)
#   adding: kaggle/working/Spain_Donostia San Sebastián.csv (deflated 83%)
#   adding: kaggle/working/Spain_Gasteiz Vitoria.csv (deflated 82%)
#   adding: kaggle/working/Spain_Granada.csv (deflated 76%)
#   adding: kaggle/working/Spain_Huelva.csv (deflated 76%)
#   adding: kaggle/working/Spain_Las Palmas de Gran Canaria.csv (deflated 84%)
#   adding: kaggle/working/Spain_Madrid.csv (deflated 78%)
#   adding: kaggle/working/Spain_Málaga.csv (deflated 76%)
#   adding: kaggle/working/Spain_Murcia.csv (deflated 78%)
#   adding: kaggle/working/Spain_Oviedo.csv (deflated 78%)
#   adding: kaggle/working/Spain_Palma.csv (deflated 76%)
#   adding: kaggle/working/Spain_Pamplona.csv (deflated 80%)
#   adding: kaggle/working/Spain_Salamanca.csv (deflated 79%)
#   adding: kaggle/working/Spain_Santa Cruz de Tenerife.csv (deflated 83%)
#   adding: kaggle/working/Spain_Santander.csv (deflated 80%)
#   adding: kaggle/working/Spain_Sevilla.csv (deflated 76%)
#   adding: kaggle/working/Spain_Valencia.csv (deflated 79%)
#   adding: kaggle/working/Spain_Valladolid.csv (deflated 78%)
#   adding: kaggle/working/Spain_Zaragoza.csv (deflated 75%)
#   adding: kaggle/working/Sri Lanka_Colombo.csv (deflated 88%)
#   adding: kaggle/working/Sweden_Göteborg.csv (deflated 78%)
#   adding: kaggle/working/Sweden_Malmö.csv (deflated 76%)
#   adding: kaggle/working/Sweden_Stockholm.csv (deflated 78%)
#   adding: kaggle/working/Sweden_Uppsala.csv (deflated 80%)
#   adding: kaggle/working/Switzerland_Zürich.csv (deflated 80%)
#   adding: kaggle/working/Taiwan_Douliu.csv (deflated 78%)
#   adding: kaggle/working/Taiwan_Hsinchu.csv (deflated 78%)
#   adding: kaggle/working/Taiwan_Kaohsiung.csv (deflated 79%)
#   adding: kaggle/working/Taiwan_Keelung.csv (deflated 78%)
#   adding: kaggle/working/Taiwan_Taichung.csv (deflated 79%)
#   adding: kaggle/working/Taiwan_Tainan.csv (deflated 78%)
#   adding: kaggle/working/Taiwan_Taipei.csv (deflated 78%)
#   adding: kaggle/working/Taiwan_Taitung City.csv (deflated 81%)
#   adding: kaggle/working/Taiwan_Taoyuan City.csv (deflated 79%)
#   adding: kaggle/working/Tajikistan_Dushanbe.csv (deflated 84%)
#   adding: kaggle/working/Thailand_Bangkok.csv (deflated 81%)
#   adding: kaggle/working/Thailand_Chiang Mai.csv (deflated 82%)
#   adding: kaggle/working/Thailand_Chon Buri.csv (deflated 83%)
#   adding: kaggle/working/Thailand_Lampang.csv (deflated 81%)
#   adding: kaggle/working/Thailand_Nakhon Pathom.csv (deflated 82%)
#   adding: kaggle/working/Thailand_Rayong.csv (deflated 82%)
#   adding: kaggle/working/Thailand_Samut Prakan.csv (deflated 82%)
#   adding: kaggle/working/The Netherlands_Amsterdam.csv (deflated 80%)
#   adding: kaggle/working/The Netherlands_Breda.csv (deflated 79%)
#   adding: kaggle/working/The Netherlands_Dordrecht.csv (deflated 80%)
#   adding: kaggle/working/The Netherlands_Eindhoven.csv (deflated 80%)
#   adding: kaggle/working/The Netherlands_Groningen.csv (deflated 81%)
#   adding: kaggle/working/The Netherlands_Haarlem.csv (deflated 79%)
#   adding: kaggle/working/The Netherlands_Maastricht.csv (deflated 81%)
#   adding: kaggle/working/The Netherlands_Nijmegen.csv (deflated 80%)
#   adding: kaggle/working/The Netherlands_Rotterdam.csv (deflated 80%)
#   adding: kaggle/working/The Netherlands_The Hague.csv (deflated 79%)
#   adding: kaggle/working/The Netherlands_Utrecht.csv (deflated 79%)
#   adding: kaggle/working/Türkiye_Adana.csv (deflated 77%)
#   adding: kaggle/working/Türkiye_Adapazarı.csv (deflated 77%)
#   adding: kaggle/working/Türkiye_Ankara.csv (deflated 76%)
#   adding: kaggle/working/Türkiye_Antakya.csv (deflated 80%)
#   adding: kaggle/working/Türkiye_Balıkesir.csv (deflated 79%)
#   adding: kaggle/working/Türkiye_Bursa.csv (deflated 76%)
#   adding: kaggle/working/Türkiye_Denizli.csv (deflated 79%)
#   adding: kaggle/working/Türkiye_Erzurum.csv (deflated 76%)
#   adding: kaggle/working/Türkiye_Eskişehir.csv (deflated 80%)
#   adding: kaggle/working/Türkiye_Istanbul.csv (deflated 77%)
#   adding: kaggle/working/Türkiye_İzmir.csv (deflated 78%)
#   adding: kaggle/working/Türkiye_İzmit.csv (deflated 77%)
#   adding: kaggle/working/Türkiye_Kayseri.csv (deflated 77%)
#   adding: kaggle/working/Türkiye_Konya.csv (deflated 77%)
#   adding: kaggle/working/Türkiye_Kütahya.csv (deflated 78%)
#   adding: kaggle/working/Türkiye_Samsun.csv (deflated 77%)
#   adding: kaggle/working/Türkiye_Sivas.csv (deflated 78%)
#   adding: kaggle/working/Türkiye_Trabzon.csv (deflated 78%)
#   adding: kaggle/working/Turkmenistan_Ashgabat.csv (deflated 85%)
#   adding: kaggle/working/Uganda_Kampala.csv (deflated 85%)
#   adding: kaggle/working/Ukraine_Dnipro.csv (deflated 79%)
#   adding: kaggle/working/Ukraine_Ivano-Frankivsk.csv (deflated 82%)
#   adding: kaggle/working/Ukraine_Kamianske.csv (deflated 80%)
#   adding: kaggle/working/Ukraine_Kryvyi Rih.csv (deflated 81%)
#   adding: kaggle/working/Ukraine_Kyiv.csv (deflated 79%)
#   adding: kaggle/working/Ukraine_Lviv.csv (deflated 78%)
#   adding: kaggle/working/Ukraine_Odessa.csv (deflated 81%)
#   adding: kaggle/working/Ukraine_Ternopil.csv (deflated 81%)
#   adding: kaggle/working/Ukraine_Zaporizhia.csv (deflated 81%)
#   adding: kaggle/working/United Arab Emirates_Abu Dhabi.csv (deflated 83%)
#   adding: kaggle/working/United Arab Emirates_Dubai.csv (deflated 84%)
#   adding: kaggle/working/United Kingdom_Belfast.csv (deflated 80%)
#   adding: kaggle/working/United Kingdom_Birmingham.csv (deflated 80%)
#   adding: kaggle/working/United Kingdom_Bristol.csv (deflated 79%)
#   adding: kaggle/working/United Kingdom_Cardiff.csv (deflated 79%)
#   adding: kaggle/working/United Kingdom_Coventry.csv (deflated 80%)
#   adding: kaggle/working/United Kingdom_Edinburgh.csv (deflated 79%)
#   adding: kaggle/working/United Kingdom_Glasgow.csv (deflated 80%)
#   adding: kaggle/working/United Kingdom_Leeds.csv (deflated 78%)
#   adding: kaggle/working/United Kingdom_Leicester.csv (deflated 80%)
#   adding: kaggle/working/United Kingdom_Liverpool.csv (deflated 80%)
#   adding: kaggle/working/United Kingdom_London.csv (deflated 78%)
#   adding: kaggle/working/United Kingdom_Luton.csv (deflated 87%)
#   adding: kaggle/working/United Kingdom_Manchester.csv (deflated 79%)
#   adding: kaggle/working/United Kingdom_Newport.csv (deflated 79%)
#   adding: kaggle/working/United Kingdom_Norwich.csv (deflated 80%)
#   adding: kaggle/working/United Kingdom_Plymouth.csv (deflated 80%)
#   adding: kaggle/working/United Kingdom_Preston.csv (deflated 79%)
#   adding: kaggle/working/United Kingdom_Reading.csv (deflated 80%)
#   adding: kaggle/working/United Kingdom_Sheffield.csv (deflated 80%)
#   adding: kaggle/working/United Kingdom_Southend-on-Sea.csv (deflated 81%)
#   adding: kaggle/working/United Kingdom_Swansea.csv (deflated 79%)
#   adding: kaggle/working/United States_Albuquerque.csv (deflated 81%)
#   adding: kaggle/working/United States_Atlanta.csv (deflated 79%)
#   adding: kaggle/working/United States_Austin.csv (deflated 81%)
#   adding: kaggle/working/United States_Baltimore.csv (deflated 81%)
#   adding: kaggle/working/United States_Boise.csv (deflated 79%)
#   adding: kaggle/working/United States_Boston.csv (deflated 81%)
#   adding: kaggle/working/United States_Brooklyn.csv (deflated 80%)
#   adding: kaggle/working/United States_Charlotte.csv (deflated 81%)
#   adding: kaggle/working/United States_Chicago.csv (deflated 79%)
#   adding: kaggle/working/United States_Columbia.csv (deflated 85%)
#   adding: kaggle/working/United States_Columbus.csv (deflated 81%)
#   adding: kaggle/working/United States_Dallas.csv (deflated 79%)
#   adding: kaggle/working/United States_Denver.csv (deflated 81%)
#   adding: kaggle/working/United States_Detroit.csv (deflated 80%)
#   adding: kaggle/working/United States_El Paso.csv (deflated 80%)
#   adding: kaggle/working/United States_Fort Worth.csv (deflated 82%)
#   adding: kaggle/working/United States_Fresno.csv (deflated 80%)
#   adding: kaggle/working/United States_Hartford.csv (deflated 81%)
#   adding: kaggle/working/United States_Honolulu.csv (deflated 84%)
#   adding: kaggle/working/United States_Houston.csv (deflated 80%)
#   adding: kaggle/working/United States_Indianapolis.csv (deflated 81%)
#   adding: kaggle/working/United States_Jackson.csv (deflated 81%)
#   adding: kaggle/working/United States_Jacksonville.csv (deflated 82%)
#   adding: kaggle/working/United States_Las Vegas.csv (deflated 81%)
#   adding: kaggle/working/United States_Little Rock.csv (deflated 84%)
#   adding: kaggle/working/United States_Los Angeles.csv (deflated 81%)
#   adding: kaggle/working/United States_Madison.csv (deflated 81%)
#   adding: kaggle/working/United States_Manhattan.csv (deflated 81%)
#   adding: kaggle/working/United States_Memphis.csv (deflated 82%)
#   adding: kaggle/working/United States_Miami.csv (deflated 81%)
#   adding: kaggle/working/United States_Milwaukee.csv (deflated 79%)
#   adding: kaggle/working/United States_Nashville.csv (deflated 82%)
#   adding: kaggle/working/United States_Oakland.csv (deflated 81%)
#   adding: kaggle/working/United States_Oklahoma City.csv (deflated 81%)
#   adding: kaggle/working/United States_Omaha.csv (deflated 80%)
#   adding: kaggle/working/United States_Philadelphia.csv (deflated 82%)
#   adding: kaggle/working/United States_Phoenix.csv (deflated 81%)
#   adding: kaggle/working/United States_Portland.csv (deflated 81%)
#   adding: kaggle/working/United States_Providence.csv (deflated 81%)
#   adding: kaggle/working/United States_Queens.csv (deflated 79%)
#   adding: kaggle/working/United States_Raleigh.csv (deflated 80%)
#   adding: kaggle/working/United States_Richmond.csv (deflated 82%)
#   adding: kaggle/working/United States_Sacramento.csv (deflated 82%)
#   adding: kaggle/working/United States_Saint Paul.csv (deflated 81%)
#   adding: kaggle/working/United States_Salem.csv (deflated 82%)
#   adding: kaggle/working/United States_Salt Lake City.csv (deflated 82%)
#   adding: kaggle/working/United States_San Antonio.csv (deflated 81%)
#   adding: kaggle/working/United States_San Diego.csv (deflated 81%)
#   adding: kaggle/working/United States_San Francisco.csv (deflated 82%)
#   adding: kaggle/working/United States_San Jose.csv (deflated 81%)
#   adding: kaggle/working/United States_Seattle.csv (deflated 80%)
#   adding: kaggle/working/United States_Springfield.csv (deflated 83%)
#   adding: kaggle/working/United States_Staten Island.csv (deflated 82%)
#   adding: kaggle/working/United States_Tallahassee.csv (deflated 83%)
#   adding: kaggle/working/United States_The Bronx.csv (deflated 80%)
#   adding: kaggle/working/United States_Tucson.csv (deflated 81%)
#   adding: kaggle/working/United States_Washington D.C..csv (deflated 82%)
#   adding: kaggle/working/Uzbekistan_Tashkent.csv (deflated 83%)
#   adding: kaggle/working/Vietnam_Haiphong.csv (deflated 79%)
#   adding: kaggle/working/Vietnam_Hạ Long.csv (deflated 79%)
#   adding: kaggle/working/Vietnam_Hanoi.csv (deflated 78%)
#   adding: kaggle/working/Vietnam_Ho Chi Minh City.csv (deflated 88%)
#   adding: kaggle/working/Vietnam_Huế.csv (deflated 81%)
